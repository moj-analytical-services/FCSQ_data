# %%
import pandas as pd  # for the data structures to store and manipulate tables
import pydbtools as pydb  # see https://github.com/moj-analytical-services/pydbtools
import boto3  # for working with AWS

# few things for viewing dataframes better
pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 900)
pd.set_option("display.max_colwidth", 200)

database = "familyman_dev_v2"
snapshot_date = "2021-08-19"
database_derived = "familyman_derived_dev_v1"

fcsq_database = "fcsq"

s3 = boto3.resource("s3")
bucket = s3.Bucket("alpha-family-data")

# %%
create_adopt_case_data_v1 = f"""
SELECT T1.YEAR,
            T1.QUARTER,
            T1.COURT,
            T1.CASE_NUMBER,
            T1.APP_TYPE,
            T1.CASE_APP_TYPE,
            T1.ADOPTION,
            T1.HIGH_COURT,
            T1.CONTESTED,
            T1.NUMBER_APPLICANTS,
            T1.ADOPTER_TYPE,
            date_format(T1.APP_DATE,'%d-%m-%Y') AS APP_DATE2
    FROM fcsq.adopt_apps_6_adoptions_only AS t1
    ORDER BY case_number, app_date2, court;
    
"""

create_adopt_case_data_v2 = f"""
SELECT *,(case when row_number() over (partition by case_number order by 
        APP_DATE2) = 1 then 1 else 0 end) as case_number_id
FROM __temp__.adopt_case_data_v1
"""

create_adopt_case_data_v3 = f"""
SELECT *
FROM __temp__.adopt_case_data_v2
where case_number_id = 1 and year > 2010;
"""
pydb.create_temp_table(create_adopt_case_data_v1,'adopt_case_data_v1')

pydb.create_temp_table(create_adopt_case_data_v2,'adopt_case_data_v2')
pydb.create_temp_table(create_adopt_case_data_v3,'adopt_case_data_v3')

# %% [markdown]
# ## Applicant_Info table

# %% [markdown]
# ### Drop the Applicant_Info table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_Applicant_Info = f"""
DROP TABLE IF EXISTS fcsq.Adopt_Applicant_Info;
"""
pydb.start_query_execution_and_wait(drop_Adopt_Applicant_Info)

# clean up previous Adopt_Applicant_Info files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_Applicant_Info/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'AJXMGMDPGVEFK0Y4',
#    'HostId': 'zJuXXDNT0QrJle1cddYdJxV5WoscwZogZm1igwvMVpfcf3Oc6aBwwutALTI3RXfgx3CDuifsHAo=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'zJuXXDNT0QrJle1cddYdJxV5WoscwZogZm1igwvMVpfcf3Oc6aBwwutALTI3RXfgx3CDuifsHAo=',
#     'x-amz-request-id': 'AJXMGMDPGVEFK0Y4',
#     'date': 'Thu, 07 Apr 2022 10:58:39 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_ef5cfe5e-a778-4cec-9ff6-6e4d458d712a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'TdJ4EnoEIWWxnexN3StHX7KXc3WVWV91'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_8e4406c1-938c-4b34-9c84-591b9290fe26',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'wT19q6kIo6lKe5pj0ZW1k6LZqiZI66wg'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_814aa01c-bfb5-4818-bdb4-1325d23f711f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'kvvXdIxN_jN6MvaGSsNVv_EJTZ11Yao2'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_3872f2ee-017f-448e-9de4-4740aefddd7e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '0K3Qak8sC9uZJrYmgwsWDYbZDce0dM8r'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_631c7045-d420-44a2-bb5c-1ae689cd6f13',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Q_CPpot0FlQF3MPc4jD8RLbzXNPVf6dy'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_782f57b8-42e1-46c3-a1e7-ee6157b40060',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '6Z3.EmYT885z6o9m.WKQcYu3Ip3PKyOu'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_399e9952-b387-43e5-9fad-b504e565252d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '4e8Jnxxt06t8NAYu2F_NpFhgf_qNZLTb'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_713c4512-8cb5-44fc-9805-3eb76a5421bc',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'nJCBKVTMkCiNxsiAARVvWhrYfrBk3lTc'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_02a2ff9e-8b5e-4927-a681-1a04c5c5ca8a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'aG2Jdyn6z3IXjRSQcRI7CVT4Y_z0igru'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_a1830f6b-92ba-455d-b7d7-b83160c5aa06',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'IrvqOqDv.FGAyRaxcUPCQAlWPRgkb71v'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_ee97a79a-2ba7-4911-be06-548067b997bd',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '24XABMrcEKsGtgkgfsn7EnhPDtSi6tnj'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_a96404f3-2948-4e83-8b5e-7c02b1d2a375',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'y1HWImkqPJTwHDwEPX9xYaQddASPMUzb'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_66598b95-109e-4f80-956c-cc9f954cc2e0',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'a72wR89wv3eaym._q7qmM_HYsmqBN.k3'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_8dffc7f6-0689-4db2-8a9c-5e491d33b8f7',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'C03pcAcDIlT8Qj5jQFdV0XxUCRHlLkOo'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_186a18e9-fce9-4770-b81a-df713d06f2af',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'mVKepZHpFHQ0zS59f2Cdve4NzaQKhBQr'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_1c56b311-6d26-4f3c-8fb2-88ea8fbf11ee',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'gyq9MIu7j6XkwAeQRDAi2H4c5fZhsqua'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_55b079fa-8a44-4d51-b365-5dea7bf769e9',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '0qL2K2axEKWzF34nb0Y.cxysDTqQF4A1'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_b8a5f0a8-371a-496a-b693-a07c3f26ae8a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'xYHh.iRxkQQvpNMmBHPe7Uy0begmZBeu'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_e4dee2c9-e2eb-47a0-8aad-430f31d71a2a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 's5tHpZ9oOfzsifF2zrgpbl6hRXzAp4Kq'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Applicant_Info/20220406_162555_00068_hjees_6eac87b8-5939-476e-932f-e1e15aca7b63',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '.q83F7EW6R7sQw1wlOMfD3FHAfBmqrza'}]}]

# %% [markdown]
# ### Create the Applicant_Info table in Athena

# %%
create_Adopt_Applicant_Info = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_Applicant_Info
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Applicant_Info') AS
 SELECT DISTINCT
   {database}.roles.ROLE, 
   {database}.roles.REPRESENTATIVE_ROLE, 
   {database}.roles.ROLE_MODEL, 
   {database}.roles.PARTY, 
   {database}.roles.CASE_NUMBER, 
   {database}.parties.PERSON_GIVEN_FIRST_NAME, 
   {database}.parties.PERSON_FAMILY_NAME, 
   {database}.parties.COMPANY, 
   {database}.addresses.POSTCODE, 
   {database}.parties.GENDER, 
   {database}.roles.DELETE_FLAG
FROM 
  ({database}.roles INNER JOIN {database}.parties ON {database}.roles.PARTY = {database}.parties.PARTY) 
  LEFT JOIN {database}.addresses ON {database}.roles.ADDRESS = {database}.addresses.ADDRESS
WHERE 
    (((({database}.roles.ROLE_MODEL)= 'APLZ') AND (({database}.roles.DELETE_FLAG)= 'N')) 
    OR ((({database}.roles.ROLE_MODEL)= 'APLA') AND (({database}.roles.DELETE_FLAG)= 'N'))
    OR ((({database}.roles.ROLE_MODEL)= 'APLC') AND (({database}.roles.DELETE_FLAG)= 'N')))
    AND {database}.roles.mojap_snapshot_date = date '{snapshot_date}'
    AND {database}.parties.mojap_snapshot_date = date '{snapshot_date}'
    AND {database}.addresses.mojap_snapshot_date = date '{snapshot_date}';
"""

pydb.start_query_execution_and_wait(create_Adopt_Applicant_Info)
# Out:
# {'QueryExecutionId': '420d9380-8801-4fe2-85fc-66d1137c1ab8',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_Applicant_Info\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Applicant_Info') AS\n SELECT DISTINCT\n   familyman_dev_v2.roles.ROLE, \n   familyman_dev_v2.roles.REPRESENTATIVE_ROLE, \n   familyman_dev_v2.roles.ROLE_MODEL, \n   familyman_dev_v2.roles.PARTY, \n   familyman_dev_v2.roles.CASE_NUMBER, \n   familyman_dev_v2.parties.PERSON_GIVEN_FIRST_NAME, \n   familyman_dev_v2.parties.PERSON_FAMILY_NAME, \n   familyman_dev_v2.parties.COMPANY, \n   familyman_dev_v2.addresses.POSTCODE, \n   familyman_dev_v2.parties.GENDER, \n   familyman_dev_v2.roles.DELETE_FLAG\nFROM \n  (familyman_dev_v2.roles INNER JOIN familyman_dev_v2.parties ON familyman_dev_v2.roles.PARTY = familyman_dev_v2.parties.PARTY) \n  LEFT JOIN familyman_dev_v2.addresses ON familyman_dev_v2.roles.ADDRESS = familyman_dev_v2.addresses.ADDRESS\nWHERE \n    ((((familyman_dev_v2.roles.ROLE_MODEL)= 'APLZ') AND ((familyman_dev_v2.roles.DELETE_FLAG)= 'N')) \n    OR (((familyman_dev_v2.roles.ROLE_MODEL)= 'APLA') AND ((familyman_dev_v2.roles.DELETE_FLAG)= 'N'))\n    OR (((familyman_dev_v2.roles.ROLE_MODEL)= 'APLC') AND ((familyman_dev_v2.roles.DELETE_FLAG)= 'N')))\n    AND familyman_dev_v2.roles.mojap_snapshot_date = date '2021-08-19'\n    AND familyman_dev_v2.parties.mojap_snapshot_date = date '2021-08-19'\n    AND familyman_dev_v2.addresses.mojap_snapshot_date = date '2021-08-19'",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/420d9380-8801-4fe2-85fc-66d1137c1ab8'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 10, 58, 41, 116000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 10, 59, 12, 570000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 31011,
#   'DataScannedInBytes': 1051168236,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/420d9380-8801-4fe2-85fc-66d1137c1ab8-manifest.csv',
#   'TotalExecutionTimeInMillis': 31454,
#   'QueryQueueTimeInMillis': 316,
#   'QueryPlanningTimeInMillis': 1699,
#   'ServiceProcessingTimeInMillis': 127},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Applicant_Info validation

# %%
Adopt_Applicant_Info_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_Applicant_Info")
Adopt_Applicant_Info_count
# Out:
#      count
# 0  1986081

# %% [markdown]
# ## adopt_respondent_info table

# %% [markdown]
# ### Drop the adopt_respondent_info table if it already exists and remove its data from the S3 bucket

# %%
drop_adopt_respondent_info = f"""
DROP TABLE IF EXISTS fcsq.adopt_respondent_info;
"""
pydb.start_query_execution_and_wait(drop_adopt_respondent_info)

# clean up previous adopt_respondent_info files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/adopt_respondent_info/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'Z5P6KNTDNFPSE1TV',
#    'HostId': 'ZA26eCDpG/vIyxJl0CKizN/7qQ0uEoO7+GJZSSXAktQw5dizuicjVUJwj+DrHD0/XS2dKzxNGAs=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'ZA26eCDpG/vIyxJl0CKizN/7qQ0uEoO7+GJZSSXAktQw5dizuicjVUJwj+DrHD0/XS2dKzxNGAs=',
#     'x-amz-request-id': 'Z5P6KNTDNFPSE1TV',
#     'date': 'Thu, 07 Apr 2022 10:59:27 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_d5c29a60-99ec-4452-b781-1e2543d71495',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'j.TsImn5i8KmbwL4Y4W7SzxnFXxtMeNS'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_af05aa73-cbeb-46cc-bd78-9f4d11cb9f39',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Z0WkmUrvG0FX5sQ1ADVeKRCT8rNqV8zD'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_e3368676-6604-492f-b119-d561bbd91736',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Ons0l2LQb2P9kbCTzyFpWVObLNALiHfO'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_179617d6-1eae-4abb-8371-e87e3593f95b',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ylklQ7vQWy9ByorDJA0JF1BxmwRr7e10'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_4ff14abd-1087-44b7-963a-ea7f0dfe3bb3',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'lfBV.ocoGLjUbXqrgIyAhNJ.OffP4qKv'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_35d7d627-17bb-4133-829f-5ec2cedccc87',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'o_vEhPiuS_cKhJau.xg9Fi2hu8Zzk02Q'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_16da6bab-7cf6-47d5-acfb-8a2db1eb8fd5',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ugE0lQk9j25Ungm6RHKPV529IupctreV'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_710b92c6-bb8d-4f90-a652-735511ea09f2',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Woca06TNjxMtzVszvT9wlioDTRZQqxLR'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_745b9250-7ff0-45e5-938b-c496d4f0c32e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'iFU6j6zwLx7hGCmwd4wlo9vEeC4gXB1d'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_2832d816-de7f-4939-915f-e4b914046c7f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'BcfVcAG_rqqSq0iYvpuYmLgFtLhi8Rgn'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_a35efea5-67c5-4ccd-9b24-984e9be8a96b',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'lRly6whE4qixBInmcoWgelUhwehN8DWh'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_b6e620b8-0eb8-4d29-b92d-6b8d9121bcce',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'eb.JgBeebEijGyoDgCqUYP11wDpDs0yn'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_685551a3-1314-4707-80f5-8a14c0c3e566',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '3XhZxkHAsazRS9atKckt.CtDvpNuZd7i'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_937d28dd-95a5-410a-a871-21b0e6a83107',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '9M09wN4aRE0p3VHglJhzan23DAnze_2h'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_1bd3a2fa-9a95-46ab-974b-fb0313263ceb',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'tC6bltfBYJj3Gkm9X1018a4CmdEGdnbt'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_3ffda8de-17b3-403f-a413-73ac8b90293b',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'g5Q0FiRqDFmpLYBUTUVMNTKt3cU8XPIN'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_54b582fb-20de-4733-b61a-8803939c9574',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'UNNGUPVKB_PiUODxvoEsl_Gj.PEMtWeO'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_bd505244-69b0-462a-8cc9-65e4489e4622',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'bVEfCTTDBlzpTK_xwR4I260pIlCCzZ2y'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_5a79535b-4e25-4b73-b746-788dc9ad6119',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '1fLY_3j6KL5d17WXQvNiA6Mom_8LnASS'},
#    {'Key': 'fcsq_processing/Adoption/adopt_respondent_info/20220406_162641_00052_23yqr_661b0a77-974e-4a45-925f-0cc953848332',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'eBcNd4vlOfs2jpT8YKfemCjL8_38bg9Y'}]}]

# %% [markdown]
# ### Create the adopt_respondent_info table in Athena

# %%
create_adopt_respondent_info = f"""
CREATE TABLE IF NOT EXISTS fcsq.adopt_respondent_info
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/adopt_respondent_info') AS
SELECT DISTINCT
  {database}.roles.ROLE, 
  {database}.roles.REPRESENTATIVE_ROLE, 
  {database}.roles.ROLE_MODEL, 
  {database}.roles.PARTY, 
  {database}.roles.CASE_NUMBER, 
  {database}.parties.GENDER, 
  {database}.addresses.POSTCODE, 
  {database}.roles.DELETE_FLAG
FROM 
  ({database}.roles INNER JOIN {database}.parties ON {database}.roles.PARTY = {database}.parties.PARTY) 
    LEFT JOIN {database}.addresses ON {database}.roles.ADDRESS = {database}.addresses.ADDRESS
WHERE 
    ((({database}.roles.ROLE_MODEL)='RSPA') AND (({database}.roles.DELETE_FLAG)='N')) 
    OR ((({database}.roles.ROLE_MODEL)='RSPZ') AND (({database}.roles.DELETE_FLAG)='N'))
    OR ((({database}.roles.ROLE_MODEL)='RSPC') AND (({database}.roles.DELETE_FLAG)='N'))
    AND {database}.roles.mojap_snapshot_date = date '{snapshot_date}'
    AND {database}.parties.mojap_snapshot_date = date '{snapshot_date}'
    AND {database}.addresses.mojap_snapshot_date = date '{snapshot_date}';
"""

pydb.start_query_execution_and_wait(create_adopt_respondent_info)
# Out:
# {'QueryExecutionId': 'a33e4da3-df7a-4445-8371-c97b5590f024',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.adopt_respondent_info\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/adopt_respondent_info') AS\nSELECT DISTINCT\n  familyman_dev_v2.roles.ROLE, \n  familyman_dev_v2.roles.REPRESENTATIVE_ROLE, \n  familyman_dev_v2.roles.ROLE_MODEL, \n  familyman_dev_v2.roles.PARTY, \n  familyman_dev_v2.roles.CASE_NUMBER, \n  familyman_dev_v2.parties.GENDER, \n  familyman_dev_v2.addresses.POSTCODE, \n  familyman_dev_v2.roles.DELETE_FLAG\nFROM \n  (familyman_dev_v2.roles INNER JOIN familyman_dev_v2.parties ON familyman_dev_v2.roles.PARTY = familyman_dev_v2.parties.PARTY) \n    LEFT JOIN familyman_dev_v2.addresses ON familyman_dev_v2.roles.ADDRESS = familyman_dev_v2.addresses.ADDRESS\nWHERE \n    (((familyman_dev_v2.roles.ROLE_MODEL)='RSPA') AND ((familyman_dev_v2.roles.DELETE_FLAG)='N')) \n    OR (((familyman_dev_v2.roles.ROLE_MODEL)='RSPZ') AND ((familyman_dev_v2.roles.DELETE_FLAG)='N'))\n    OR (((familyman_dev_v2.roles.ROLE_MODEL)='RSPC') AND ((familyman_dev_v2.roles.DELETE_FLAG)='N'))\n    AND familyman_dev_v2.roles.mojap_snapshot_date = date '2021-08-19'\n    AND familyman_dev_v2.parties.mojap_snapshot_date = date '2021-08-19'\n    AND familyman_dev_v2.addresses.mojap_snapshot_date = date '2021-08-19'",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/a33e4da3-df7a-4445-8371-c97b5590f024'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 10, 59, 28, 508000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 10, 59, 59, 242000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 30563,
#   'DataScannedInBytes': 10043394139,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/a33e4da3-df7a-4445-8371-c97b5590f024-manifest.csv',
#   'TotalExecutionTimeInMillis': 30734,
#   'QueryQueueTimeInMillis': 118,
#   'QueryPlanningTimeInMillis': 1325,
#   'ServiceProcessingTimeInMillis': 53},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### adopt_respondent_info validation

# %%
adopt_respondent_info_count = pydb.read_sql_query("select count(*) as count from fcsq.adopt_respondent_info")
adopt_respondent_info_count
# Out:
#      count
# 0  2385362

# %% [markdown]
# ## applicants 3 table

# %%
create_adopt_applicants_1 = f"""
SELECT 	T1.role,
    T1.representative_role,
    T1.role_model,
    T1.party,
    T1.case_number,
    T1.gender,
    case when cast(gender as varchar(1)) = '1' then 'Male'
    when cast(gender as varchar(1)) = '2' then 'Female'
    else 'Unknown' end as Gender_Decode

    FROM fcsq.adopt_applicant_info AS t1
    ORDER BY t1.Case_Number;
"""
#pydb.start_query_execution_and_wait(create_adopt_applicants_1)
pydb.create_temp_table(create_adopt_applicants_1,'adopt_applicants_1')



create_adopt_applicants_2 = f"""
SELECT DISTINCT 
    T1.case_number,
    T1.party,
    max(T1.representative_role) as Rep_Role,
    max(T1.gender_decode) as Gender_Max
    from __temp__.adopt_applicants_1 AS t1
    group by Case_number, party;
"""

pydb.create_temp_table(create_adopt_applicants_2,'adopt_applicants_2')
#pydb.start_query_execution_and_wait(create_adopt_applicants_2)


create_adopt_applicants_3= f"""
SELECT t1.case_number,
    t1.party as App_Party_ID,
    t1.Rep_Role,
    t1.Gender_Max,
    case when t1.Rep_Role IS NULL then 'N'
    when t1.Rep_Role IS NOT NULL then 'Y'
    End as REPRESENTATION,
    case when Rep_Role IS NULL AND Gender_Max = 'Female' then 'Unrep_Female'
    when Rep_Role IS NULL AND Gender_Max = 'Male' then 'Unrep_Male'
    when Rep_Role IS NULL AND Gender_Max = 'Unknown' then 'Unrep_Unknown'
    when Rep_Role IS NOT NULL AND Gender_Max = 'Female' then 'Rep_Female'
    when Rep_Role IS NOT NULL AND Gender_Max = 'Male' then 'Rep_Male'
    when Rep_Role IS NOT NULL AND Gender_Max = 'Unknown' then 'Rep_Unknown'
    else '' end as App_Rep_Cat
    
    from __temp__.adopt_applicants_2 AS t1;


"""
#pydb.start_query_execution_and_wait(create_adopt_applicants_3)
pydb.create_temp_table(create_adopt_applicants_3,'adopt_applicants_3')

# %%
pydb.read_sql_query("SELECT count(*) as count from __temp__.adopt_applicants_3")
# Out:
#      count
# 0  1986062

# %%
create_adopt_respondents_1 = f"""
SELECT T1.role,
    T1.representative_role,
    T1.role_model,
    T1.party,
    T1.case_number,
    T1.gender,
    case when cast(gender as varchar(1)) = '1' then 'Male'
    when cast(gender as varchar(1)) = '2' then 'Female'
    else 'Unknown' end as Gender_Decode

    FROM fcsq.adopt_respondent_info AS t1
    ORDER BY t1.Case_Number;
"""
#pydb.start_query_execution_and_wait(create_adopt_respondents_1)
pydb.create_temp_table(create_adopt_respondents_1,'adopt_respondents_1')



create_adopt_respondents_2 = f"""
    SELECT DISTINCT T1.case_number,
        T1.party,
        max(T1.representative_role) as Rep_Role,
        max(T1.gender_decode) as Gender_Max
    from __temp__.adopt_respondents_1 AS t1
    group by Case_number, party;
"""

pydb.create_temp_table(create_adopt_respondents_2,'adopt_respondents_2')
#pydb.start_query_execution_and_wait(create_adopt_respondents_2)


create_adopt_respondents_3= f"""
SELECT t1.case_number,
    t1.party as Resp_Party_ID,
    t1.Rep_Role,
    t1.Gender_Max,
    case when t1.Rep_Role IS NULL then 'N'
    when t1.Rep_Role IS NOT NULL then 'Y'
    End as REPRESENTATION,
    case when Rep_Role IS NULL AND Gender_Max = 'Female' then 'Unrep_Female'
    when Rep_Role IS NULL AND Gender_Max = 'Male' then 'Unrep_Male'
    when Rep_Role IS NULL AND Gender_Max = 'Unknown' then 'Unrep_Unknown'
    when Rep_Role IS NOT NULL AND Gender_Max = 'Female' then 'Rep_Female'
    when Rep_Role IS NOT NULL AND Gender_Max = 'Male' then 'Rep_Male'
    when Rep_Role IS NOT NULL AND Gender_Max = 'Unknown' then 'Rep_Unknown'
    else '' end as Resp_Rep_Cat
    
    from __temp__.adopt_respondents_2 AS t1;


"""
#pydb.start_query_execution_and_wait(create_adopt_respondents_3)
pydb.create_temp_table(create_adopt_respondents_3,'adopt_respondents_3')

# %%
adopt_app_rep_final = f"""
SELECT t1.YEAR, 
    t1.QUARTER,
    t1.CASE_NUMBER, 
    t1.Court,
    t2.App_Party_ID,
    t2.Representation,
    t2.Gender_Max as App_Gender,
    t2.App_Rep_Cat          
FROM __temp__.ADOPT_CASE_DATA_v3 t1
    LEFT JOIN __temp__.ADOPT_APPLICANTS_3 t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER);

"""

pydb.create_temp_table(adopt_app_rep_final,'adopt_app_rep_final')

# %%
adopt_app_rep_final_check = "SELECT COUNT(*) as Count from __temp__.adopt_app_rep_final"
pydb.start_query_execution_and_wait(adopt_app_rep_final_check)
# Out:
# {'QueryExecutionId': '82949cb7-4911-4de7-a34c-25fdefe30c92',
#  'Query': 'SELECT COUNT(*) as Count from mojap_de_temp_alpha_user_thomasauburnmoj.adopt_app_rep_final',
#  'StatementType': 'DML',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/82949cb7-4911-4de7-a34c-25fdefe30c92.csv'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 1, 24, 820000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 1, 25, 514000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 532,
#   'DataScannedInBytes': 0,
#   'TotalExecutionTimeInMillis': 694,
#   'QueryQueueTimeInMillis': 120,
#   'QueryPlanningTimeInMillis': 80,
#   'ServiceProcessingTimeInMillis': 42},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %%
adopt_resp_rep_final = f"""
   SELECT t1.YEAR, 
        t1.QUARTER,
        t1.CASE_NUMBER, 
        t1.Court,
          t2.Resp_Party_ID,
          t2.Representation,
          t2.Gender_Max as Resp_Gender,
          t2.Resp_Rep_Cat
          
      FROM __temp__.ADOPT_CASE_DATA_v3 t1
           LEFT JOIN __temp__.ADOPT_RESPONDENTS_3 t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER);
"""

pydb.create_temp_table(adopt_resp_rep_final,'adopt_resp_rep_final')

# %%
adopt_resp_rep_final_check = "SELECT COUNT(*) as Count from __temp__.adopt_resp_rep_final"
pydb.start_query_execution_and_wait(adopt_resp_rep_final_check)
# Out:
# {'QueryExecutionId': 'b0e1e03a-ebfc-4452-8847-dfeafefa522f',
#  'Query': 'SELECT COUNT(*) as Count from mojap_de_temp_alpha_user_thomasauburnmoj.adopt_resp_rep_final',
#  'StatementType': 'DML',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/b0e1e03a-ebfc-4452-8847-dfeafefa522f.csv'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 1, 35, 912000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 1, 36, 832000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 761,
#   'DataScannedInBytes': 0,
#   'TotalExecutionTimeInMillis': 920,
#   'QueryQueueTimeInMillis': 116,
#   'QueryPlanningTimeInMillis': 108,
#   'ServiceProcessingTimeInMillis': 43},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# ## Adopt_Hearing_Events table

# %% [markdown]
# ### Drop the Adopt_Hearing_Events table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_Hearing_Events = f"""
DROP TABLE IF EXISTS fcsq.Adopt_Hearing_Events;
"""
pydb.start_query_execution_and_wait(drop_Adopt_Hearing_Events)

# clean up previous Adopt_Hearing_Events files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_Hearing_Events/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '8CZY7DT4W7P7DW9W',
#    'HostId': '669ysJiTSh/r4Biy8HNB/cTDXicfqj4pRY39XuiH2F7nSZBnyTL/dZ104dnqCZq1kzBzRQIog7s=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': '669ysJiTSh/r4Biy8HNB/cTDXicfqj4pRY39XuiH2F7nSZBnyTL/dZ104dnqCZq1kzBzRQIog7s=',
#     'x-amz-request-id': '8CZY7DT4W7P7DW9W',
#     'date': 'Thu, 07 Apr 2022 11:01:41 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_7c1e75ff-a25c-458d-9256-f388b92b65c1',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'TuTHHFqcE8ruT3VDL6P6vsZ6ehvBKgdX'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_875636f6-3721-49ab-b1f7-33775eb563a0',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'E38y2K7AO3DIFyA_NveXJRs_FbO1m9AM'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_b3d224b4-c312-44fe-8d5a-8bcbd4fd3878',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'a2xbXfTJp182zsHOBnptYty9q05DPSwz'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_7edf54b5-ab52-41db-bf01-389799b1491d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'yMRYc0Ohpq6pr.jilyeTktt6PbcAHO52'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_c86cc850-328e-4ea3-abfc-b83f3cda6c61',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'nMCo50J7wYGEpIvKl8g1QhR_ntArZQ48'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_80b0e2da-a92e-4039-b700-385a5dc5671a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'avjiRsrTgcg5kPkLH9.6HPTPX07.N_ye'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_b2e84599-5efd-405d-9bd2-5b4d83b6a199',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'uCpBS4_lM3YCO2Eszj_.HcnOhOlE6UeW'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_c04ad3c6-c053-4940-bf77-18ede087181c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ipmwv0WFX04wEl_LYRbC9MX4oPJ.l9Nq'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_e2a8e8a6-75b3-4ba9-a7e8-0a4809ee83ab',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'pzemKJ_y3scCDRSKBkSE7FoEnpoy6vf3'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_77b40f8f-2f0a-4931-bd93-7a21b7803844',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'VMiXL8aVQRQIXL9.dR7Dpc5rfcxocR1W'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_a5c4783c-eae2-43da-87f4-402a1c01f2cf',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '0bs2PKsl53wtc.PHY.AlkQ1tHkq2Y_pQ'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_41372a2b-185a-4c8b-9c7e-86a8f8626300',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'BT.dZCxjHLBMSfdhkobwT14pU0fLZekz'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_7bc80377-bdb6-4334-9e62-91dcac936431',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'aCXCuZgs1URbC2xTc.APUEHDQypwjTnt'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_f3ac6255-d522-4c16-a186-235ed1397929',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'R7SjCWDOK5jmjma68dCDYr0TJqt_I0iy'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_eae6d745-0693-49e8-af36-a3160ea69dd4',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'QcgzcppnDUIvUCtjbUERewErEwAxf.a1'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_83ee41d8-0117-424c-8ca3-c7cbde3e6e57',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'GuCGdWF5vYfPURo8pqmN3fildo1Xk_Im'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearing_Events/20220406_162839_00087_wzk86_4911057e-0e3b-4b40-b3c1-87e896fadfbf',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'dEmsSRXIi5iCad566p3Lj2a6gcq1ssoi'}]}]

# %% [markdown]
# ### Create the Adopt_Hearing_Events table in Athena

# %%
create_Adopt_Hearing_Events = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_Hearing_Events
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Hearing_Events') AS
SELECT {database}.hearings.EVENT,
  {database}.hearings.VACATED_FLAG,
  {database}.hearings.HEARING_TYPE,
  {database}.hearings.HEARING_DATE,
  {database}.events.RECEIPT_DATE,
  {database}.events.ERROR,
  {database}.events.CASE_NUMBER,
  {database}.events.EVENT_MODEL
FROM {database}.hearings
INNER JOIN {database}.events
ON {database}.hearings.EVENT            = {database}.events.EVENT
WHERE {database}.hearings.VACATED_FLAG IS NULL
AND {database}.events.ERROR             = 'N'
AND HEARING_DATE > date_parse('31-12-2009 00:00:00', '%d-%m-%Y %H:%i:%s')
AND (substring(case_number,5,1)='A' OR substring(case_number,5,1)='Z' OR substring(case_number,5,1)='C')
AND {database}.hearings.mojap_snapshot_date = date '{snapshot_date}' and {database}.events.mojap_snapshot_date = date '{snapshot_date}';
"""

pydb.start_query_execution_and_wait(create_Adopt_Hearing_Events)
# Out:
# {'QueryExecutionId': 'f9a7ff81-03f1-4466-bea0-c321ad09673e',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_Hearing_Events\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Hearing_Events') AS\nSELECT familyman_dev_v2.hearings.EVENT,\n  familyman_dev_v2.hearings.VACATED_FLAG,\n  familyman_dev_v2.hearings.HEARING_TYPE,\n  familyman_dev_v2.hearings.HEARING_DATE,\n  familyman_dev_v2.events.RECEIPT_DATE,\n  familyman_dev_v2.events.ERROR,\n  familyman_dev_v2.events.CASE_NUMBER,\n  familyman_dev_v2.events.EVENT_MODEL\nFROM familyman_dev_v2.hearings\nINNER JOIN familyman_dev_v2.events\nON familyman_dev_v2.hearings.EVENT            = familyman_dev_v2.events.EVENT\nWHERE familyman_dev_v2.hearings.VACATED_FLAG IS NULL\nAND familyman_dev_v2.events.ERROR             = 'N'\nAND HEARING_DATE > date_parse('31-12-2009 00:00:00', '%d-%m-%Y %H:%i:%s')\nAND (substring(case_number,5,1)='A' OR substring(case_number,5,1)='Z' OR substring(case_number,5,1)='C')\nAND familyman_dev_v2.hearings.mojap_snapshot_date = date '2021-08-19' and familyman_dev_v2.events.mojap_snapshot_date = date '2021-08-19'",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/f9a7ff81-03f1-4466-bea0-c321ad09673e'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 1, 43, 577000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 1, 53, 770000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 10040,
#   'DataScannedInBytes': 2648141523,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/f9a7ff81-03f1-4466-bea0-c321ad09673e-manifest.csv',
#   'TotalExecutionTimeInMillis': 10193,
#   'QueryQueueTimeInMillis': 112,
#   'QueryPlanningTimeInMillis': 849,
#   'ServiceProcessingTimeInMillis': 41},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adopt_Hearing_Events validation

# %%
Adopt_Hearing_Events_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_Hearing_Events")
Adopt_Hearing_Events_count
# Out:
#      count
# 0  1974912

# %% [markdown]
# ## Adopt_Hearings_Cases table

# %% [markdown]
# ### Drop the Adopt_Hearings_Cases table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_Hearings_Cases = f"""
DROP TABLE IF EXISTS fcsq.Adopt_Hearings_Cases;
"""
pydb.start_query_execution_and_wait(drop_Adopt_Hearings_Cases)

# clean up previous Adopt_Hearings_Cases files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_Hearings_Cases/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'VKPA6J146C33XFP7',
#    'HostId': '6f8f7QAfk07Rtdwx2jtySHVoQmpcgb3RiXXO+GSISdQ8DiI+phtZ5eIu676kXvjURweCe/Tso4U=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': '6f8f7QAfk07Rtdwx2jtySHVoQmpcgb3RiXXO+GSISdQ8DiI+phtZ5eIu676kXvjURweCe/Tso4U=',
#     'x-amz-request-id': 'VKPA6J146C33XFP7',
#     'date': 'Thu, 07 Apr 2022 11:02:03 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_f64cab54-a0c5-450e-9a75-be7836f690ec',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'oXhjMlYxqvsg6E774yY89dqMhdORD0jP'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_0534ebc0-ef79-4027-bc45-4d646ce726cd',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'IIKbC00woTimIKtoxId5hy87TUWiHp4.'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_a09ad23a-3683-4eee-82de-aa9509fb3f55',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '4sZSOY9SknY2GkawfUWud5UxIr1rJDMP'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_31c3d4d6-67dc-4104-9d5b-adf13948c33a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '49Lwav2lfHRMVouRFlIf93d9jLRdQrS4'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_a9d2d4d4-eefc-4be4-89c8-71bc27d6fa53',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'IeNUjdRqStdnAqX366Nm6hxmI7fcHgb_'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_499c6c0f-5fc2-4b72-81e3-ae6fdb01d684',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'n0Dv1h4rApm7ys8hp0ZPbG.c5Di4L_pQ'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_118eeb2a-1d0e-4e46-be56-273f8c9c5d0b',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '_VZfyjN1qc4T.mvzX0P2dNOoIfjV3Uha'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_25df4890-1267-4eda-9920-7c9ad15e6cde',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'NNAkXFIln.4V6FUFd0GLqoNIsr0saypG'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_7ac18594-113c-438c-8c30-77b6f100ce3f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'K5PFyQ_5po43ThpXBcIPRrEMynLS60AI'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_b236d48b-72a4-4bbc-85b5-e0ccfc123823',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'CS431NIkCKALYt9zgni_ZKokJ4MSuzyK'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_2f9f6e01-5e0b-4d38-947b-1d30a66a071e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Y8BDUWLLwAMmftZhLHQ6aIkbltilCFd7'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_580187c2-0e87-4fba-86b2-7347cddf0737',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'pSPDsKni.AUF6tqZt8kLx5mwoTYe.XRS'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_e6dd4b9f-cee2-4016-9669-d76f1b8d87a7',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '9OnH48pO7XqplEK8u3DD_1jfwz8wa4H9'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_0d091604-7fad-4c88-b2a7-fe416deb3d9c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '1LPon05b8ygT1M0Gp9.z4xC7lL7hijhv'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_21c28433-8d7e-42be-92eb-6279a7c5c511',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '56xYsEK09tSg6m3nLj_eNt3AZ4Tg1co_'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_59ebf353-1a69-47fb-9797-8c199d7302b0',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'BQ4c0gW5lTXBwV6fgklIY7dd.AtIZZVW'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_7e957a87-0292-4928-8407-561aa52c004a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Jslx1FG9dFWvpyv0f8124BfVUCHa41z1'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_a608b213-f581-48a2-a72c-50a681e1a217',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'rL15Ffl9S3nSBLkIENp1PJZ1hd.m_lIO'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_66b307b1-033c-47c8-b319-9dfd49605a23',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'xOl8V0m5vcGTysLbgV0jBxlLzS0pmVrG'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_05e94977-f018-4389-b3b4-b11b0ea3f122',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'd7Tq9mg4nRRBo1rsf5fVomzRp4rkhXuV'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_995e6b53-fad0-48e8-826c-c1ca4a0aa4f7',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'vhRRwsDtpsEKkeNNNewK1uuXWSe6w36O'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_eb99896c-f5c7-4f6c-9a8d-974090fd194d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'KlvOlmPStJjwbxHYzUpCL42SKZxb27sb'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_04214a1f-6f45-466d-ac76-7f59afe2fd25',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'L306SY3pO1X_jFxhWrYafTmXEW17oDwv'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Hearings_Cases/20220406_162900_00074_8wft4_ff9ff4e7-a6fe-465d-b437-f26e3fea1c45',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '6xrKQvN77Wxyd4KNWYjDeZ_..mcvc2ID'}]}]

# %% [markdown]
# ### Create the Adopt_Hearings_Cases table in Athena

# %%
"""
Equivalent to Hearings_Adopt_V3
"""

create_Adopt_Hearings_Cases = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_Hearings_Cases
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Hearings_Cases') AS
select t1.case_number,
    t1.error,
    t1.event,
    t1.event_model,
    t1.hearing_date,
    t1.hearing_type,
    t1.receipt_date,
    t1.vacated_flag,
    substring(Case_Number,5,1) AS Case_Type
    from fcsq.Adopt_Hearing_Events AS t1
    where t1.event_model in ('A8', 'A90', 'A91', 'G60')
    order by t1.case_number, t1.receipt_date;
"""

pydb.start_query_execution_and_wait(create_Adopt_Hearings_Cases)

create_Adopt_Hearings_Cases_v2 = f"""
SELECT *,
(case when row_number() over (partition by Case_Number order by receipt_date) = 1 then 1 else 0 end) as Case_Number_ID
FROM fcsq.Adopt_Hearings_Cases
"""

pydb.create_temp_table(create_Adopt_Hearings_Cases_v2,'adopt_hearings_cases_v2')
pydb.start_query_execution_and_wait(create_Adopt_Hearings_Cases_v2)
# Out:
# {'QueryExecutionId': '0578f395-b1d9-4d7e-a9ea-966d76ec448c',
#  'Query': 'SELECT *,\n(case when row_number() over (partition by Case_Number order by receipt_date) = 1 then 1 else 0 end) as Case_Number_ID\nFROM fcsq.Adopt_Hearings_Cases',
#  'StatementType': 'DML',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/0578f395-b1d9-4d7e-a9ea-966d76ec448c.csv'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 2, 19, 987000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 2, 23, 783000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 3618,
#   'DataScannedInBytes': 2379198,
#   'TotalExecutionTimeInMillis': 3796,
#   'QueryQueueTimeInMillis': 123,
#   'QueryPlanningTimeInMillis': 107,
#   'ServiceProcessingTimeInMillis': 55},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adopt_Hearings_Cases validation

# %%
Adopt_Hearings_Cases_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_Hearings_Cases")
Adopt_Hearings_Cases_count
# Out:
#     count
# 0  323515

# %% [markdown]
# ## Hearing_Adopt_Applicants table

# %% [markdown]
# ### Drop the Hearing_Adopt_Applicants table if it already exists and remove its data from the S3 bucket

# %%
drop_Hearing_Adopt_Applicants = f"""
DROP TABLE IF EXISTS fcsq.Hearing_Adopt_Applicants;
"""
pydb.start_query_execution_and_wait(drop_Hearing_Adopt_Applicants)

# clean up previous Hearing_Adopt_Applicants files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Hearing_Adopt_Applicants/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'WFNMNHYZ7QWN10E8',
#    'HostId': 'MiBfgF4ti7DpZnSuthX2yjP27SJgea5F5tJOl+EI6JJCRKU+L+XClcr7jZOgLxXWipSpGHf/W84=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'MiBfgF4ti7DpZnSuthX2yjP27SJgea5F5tJOl+EI6JJCRKU+L+XClcr7jZOgLxXWipSpGHf/W84=',
#     'x-amz-request-id': 'WFNMNHYZ7QWN10E8',
#     'date': 'Thu, 07 Apr 2022 11:02:33 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_84695170-0953-4d56-a458-26f5cad30461',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'GpVAF7h2G5fLswBHbyGMxTquxgheBJFH'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_9b6c361f-5f2d-4d52-a998-4fcdc94f8605',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'F.rw7Na.0Lml6Wu4rajCY0SBz4Cs9tsx'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_9def5d93-3832-4ae7-b019-e3411344ee39',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'FAy7SBYO8p56cDOhEt3eJhduZXquIFvP'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_f4a12793-3039-44d1-94ad-9af8135488b4',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'H_FomyCwlYP5__.sYAtLUe5x0yjACdbu'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_030830f5-09c8-48bf-aaaf-a9374ae16243',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'wv1qzeKVqW85BfwoQcwf58Te2u.7VpSS'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_a841587b-688a-4eef-9153-ffa05494b45b',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'neL79oeWwERjPplCrI1JeGZ.uMvq7A3L'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_9794e8bc-9998-4ce7-a258-e1c856cae305',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'BD36UJqaZZVja6V6603bQXtgv8KoAjpe'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_acbbf13f-a016-4582-9244-c838bbdbba09',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'dnW4hC.6ui6Lq0Pa3zoXnZpW4R0nobl4'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_8e0aa4ee-59ec-47f8-9f05-50506aef4c72',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ncF4Y2r4qOn6sACwzlifzvlf9Xd21qGw'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_db35c822-11b7-41d0-9d7b-0f3ede99cfba',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'sCqkjBpHLk7FtK2e2XgTr70ouqhcSAO2'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_05755b5b-5de8-466b-aea2-fef45967aa1d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Jw8s7qoz5gIEGBJUHRDnjQiovfTMfp2f'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_197b8cbf-3ce7-40fe-a892-bcd0e28fc1fd',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '9gRvxJep4jBCsMOIerA2SlXHDArfu7r1'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_21f72296-e647-44a0-a651-b6993d37db34',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'wy84PtySTGOzRsErTjDFsoMPuxtw0DIk'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_de141830-176e-47ec-b408-d2161040268f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'OYHlVAmqWUGX6Bmqf4LeL1SxWk7hkb3x'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_a079ecf1-6751-4e6f-99a3-b6d46929ad7d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'hUAc6KxdZziY6NuoAivYvX_LBYnBxWzX'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_fd989da2-c693-44fc-9d53-709730e2f1ba',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 't2_04wukLHToGsxs1TdOXfXjb1P74bCO'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_1f955016-d992-445e-8f2f-baf4d4fa04fc',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'SNFX_mFqOyVYpR2.KSLA31vEr_y9PtoX'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_90595f1b-1190-423e-a0c5-987565b7d923',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'X8htrUcps9YW_MS2mpgnarC_KLQFeOeF'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_27094c7c-3892-4c1a-b572-ae0d0d54c8ea',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'xLPGeVmdIG5AIFz2sr3Utsbw.qXxvMbc'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_8edf05de-d6bb-4b9c-913e-953b67fe334e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Amd.9zUihpmXNQxkeW6pCjIGWW1He5VU'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_599b0c32-2295-4956-a221-2bf7b412ff02',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'H1NUHw2UVDdrHiJDmMPqTFNG0MFRyscq'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_be78ff90-fabc-45ae-9cf9-5b6fb0e47a66',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '9lvQlJmhbnhHzL2OQRg5aZjR0Lo.H0v4'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_50669abd-944d-4f6e-96f8-b1fb950af83a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'K9EDHL6k9focOgklqbs05vHDRU9Rnf7_'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_d2f95e9e-1710-45d4-85d9-98ca890a4fbf',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'JRsopHqOfo6EGQUNYHCGZQSz.ecpY4QL'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_2a7add2c-8762-46d0-98c1-c140a6e7576d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ie2__eudY4fK5Zefq9GlGPvQslToRLe.'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_b5ae1898-fde1-47e3-a89a-34c40cef230f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'M.7OSjfSMy98uEUXzEP8_ayY0he5N.gL'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_e6675d61-60b2-4205-bb14-a27d640f188c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'jnLK4W9AlgdDC1Vy6H_f1q3WjE0I59i6'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_45d541d0-46bb-4b3c-a352-c50cb4d8ddf3',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'IzocUmP.GnzSXGo3RDs6uaGvVV1o1q4G'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Applicants/20220406_162926_00033_rdxi3_bcbf81c6-3886-4fe7-bb64-988792388922',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '9LZtXYhc4YHA_flmUx8V3Wf2FEtmlNFe'}]}]

# %% [markdown]
# ### Create the Hearing_Adopt_Applicants table in Athena

# %%
create_Hearing_Adopt_Applicants = f"""
CREATE TABLE IF NOT EXISTS fcsq.Hearing_Adopt_Applicants
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Hearing_Adopt_Applicants') AS
SELECT t1.*,
t2.Case_Number_ID AS Hearing_Count
FROM __temp__.ADOPT_APP_REP_FINAL t1
LEFT JOIN __temp__.Adopt_Hearings_Cases_v2 t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER)
where t2.Case_Number_ID > 0;
"""

pydb.start_query_execution_and_wait(create_Hearing_Adopt_Applicants)
# Out:
# {'QueryExecutionId': 'a296c13f-3fde-4b5e-838e-c4feea2e9613',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Hearing_Adopt_Applicants\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Hearing_Adopt_Applicants') AS\nSELECT t1.*,\nt2.Case_Number_ID AS Hearing_Count\nFROM mojap_de_temp_alpha_user_thomasauburnmoj.ADOPT_APP_REP_FINAL t1\nLEFT JOIN mojap_de_temp_alpha_user_thomasauburnmoj.Adopt_Hearings_Cases_v2 t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER)\nwhere t2.Case_Number_ID > 0",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/a296c13f-3fde-4b5e-838e-c4feea2e9613'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 2, 34, 973000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 2, 39, 710000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 4402,
#   'DataScannedInBytes': 2326240,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/a296c13f-3fde-4b5e-838e-c4feea2e9613-manifest.csv',
#   'TotalExecutionTimeInMillis': 4737,
#   'QueryQueueTimeInMillis': 250,
#   'QueryPlanningTimeInMillis': 297,
#   'ServiceProcessingTimeInMillis': 85},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Hearing_Adopt_Applicants validation

# %%
Hearing_Adopt_Applicants_count = pydb.read_sql_query("select count(*) as count from fcsq.Hearing_Adopt_Applicants")
Hearing_Adopt_Applicants_count
# Out:
#    count
# 0  95784

# %% [markdown]
# ## Hearing_Adopt_Respondents table

# %% [markdown]
# ### Drop the Hearing_Adopt_Respondents table if it already exists and remove its data from the S3 bucket

# %%
drop_Hearing_Adopt_Respondents = f"""
DROP TABLE IF EXISTS fcsq.Hearing_Adopt_Respondents;
"""
pydb.start_query_execution_and_wait(drop_Hearing_Adopt_Respondents)

# clean up previous Hearing_Adopt_Respondents files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Hearing_Adopt_Respondents/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '3Q5WAKSD00PT8W1W',
#    'HostId': '27qdPJp1oM0LRH41J9SFnzOxDwiVQEIOB4diIOyZWuYtoZy/4HN2k4J+2AJ+tWVDkRFzdwJMd6Y=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': '27qdPJp1oM0LRH41J9SFnzOxDwiVQEIOB4diIOyZWuYtoZy/4HN2k4J+2AJ+tWVDkRFzdwJMd6Y=',
#     'x-amz-request-id': '3Q5WAKSD00PT8W1W',
#     'date': 'Thu, 07 Apr 2022 11:02:50 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_6f7da1be-a4e2-4849-ab44-5923c3e339a3',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'SpyQzWoLb5C96DocXNKLRla8evj3dBmS'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_9e2112aa-c0be-4ea6-89a5-cd83e31d6247',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'sAfIziedYi1jnRuhyulNgTi2tK2Q5U8p'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_50871d1f-c88b-4213-b739-13a9176f8524',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ytTGd9qUDw1f7EtjTTiXVJlLabShPoPj'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_5ce05f06-2ac5-4722-b6b0-f2d95b037ffe',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'S0ZCEt9S0uwuZPV4hyQ_.2TrPajocOaO'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_498a93b4-0102-4012-8e23-57a23455ade8',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'wpctjLTqe4xCCAbPEQBZPdGoNtL.R5KD'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_aae01256-6b74-4ec4-9d02-53c764358c34',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'MPGKGfDP1t68VZ4KixGPgpPMj5pPayFS'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_e554b14e-4a0e-4b5d-a41b-cf6e2c9f129f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'we2zAHhJVpqU7ThJMtTRalBOx80Hrjlt'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_cf4a9855-78d3-4fec-a591-64cc6dfd001a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'TGiFbY9klJZqL0ASod8IsosufZmTRCqs'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_04aaefc3-da25-4906-a533-234399bffce3',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'XMDd6xmAHg.OVKyUgcimhXOsaZjvFkuk'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_09d5d7ee-dc2d-4a89-961e-aa9769d7d6cb',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 't72OU7zBzFVmrLRtho8vRc38AIoLiY1I'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_881605b6-b131-4e70-aead-ddc8687aadaf',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'CBZ6MVAJqe1hJzfVXCLpSBzvv.pIsmHp'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_969bb69d-203a-456a-acdf-7c8a44d88c9a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'kC_TuOgGuJF54Z1vs2DXP60HDsTeJ.MC'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_705c3bb6-4ae3-476d-8efa-099538d7b638',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'vBut1dWQgHUYwU97MvbBa3Ka3FMRhm_L'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_9f2c87a8-e514-4bb4-8d99-f545adcdc125',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'LUin2dsNjl8GJ4YVrPMzYXVY5zgrCvzj'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_1e74ea40-c934-4f02-a51f-23448a8da175',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'iWFM204k4fmJeFjup6N_cvYMi9z7lUb9'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_b83ca53f-2443-42a8-97fb-77fee05f4055',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'BSDMFV6mRqZKWNwlbyu.G0BZbAkyYAzj'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_3a651d2e-a20e-46a3-a9fa-23828ab09da4',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'H0s_M1rE2SkDpNXQ2K6nND23_piee9i9'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_5518c844-2300-4a07-a385-6230390e4617',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'dKyp2UeBnby9seUBrffyLcQ9jXdIX.U7'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_e4e89b78-441b-46bb-8da4-2a22a37387ad',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'N2dVRcFUY.y_NqBv7MnqOA8ktAEq12Wh'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_bd8f2745-24ef-49d7-a4b6-5b09d8264213',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'NYyneKCPacIgHPc_SDjXWb.D0CGm8xgO'},
#    {'Key': 'fcsq_processing/Adoption/Hearing_Adopt_Respondents/20220406_162939_00061_vwdke_cf151ed1-161b-4ed4-8be2-5ecfd73ffd2a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Jqq29E2SFQaIlMLqHKFr26Jz8F9UZFhe'}]}]

# %% [markdown]
# ### Create the Hearing_Adopt_Respondents table in Athena

# %%
create_Hearing_Adopt_Respondents = f"""
CREATE TABLE IF NOT EXISTS fcsq.Hearing_Adopt_Respondents
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Hearing_Adopt_Respondents') AS
    SELECT t1.*,
    t2.Case_Number_ID AS Hearing_Count
    FROM __temp__.ADOPT_RESP_REP_FINAL t1
    LEFT JOIN __temp__.Adopt_Hearings_Cases_v2 t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER)
    where t2.Case_Number_ID > 0;
"""

pydb.start_query_execution_and_wait(create_Hearing_Adopt_Respondents)
# Out:
# {'QueryExecutionId': '3cec9124-a2de-4959-8d8d-6e4e5fde4f0d',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Hearing_Adopt_Respondents\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Hearing_Adopt_Respondents') AS\n    SELECT t1.*,\n    t2.Case_Number_ID AS Hearing_Count\n    FROM mojap_de_temp_alpha_user_thomasauburnmoj.ADOPT_RESP_REP_FINAL t1\n    LEFT JOIN mojap_de_temp_alpha_user_thomasauburnmoj.Adopt_Hearings_Cases_v2 t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER)\n    where t2.Case_Number_ID > 0",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/3cec9124-a2de-4959-8d8d-6e4e5fde4f0d'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 2, 51, 910000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 2, 55, 2000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2902,
#   'DataScannedInBytes': 2325904,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/3cec9124-a2de-4959-8d8d-6e4e5fde4f0d-manifest.csv',
#   'TotalExecutionTimeInMillis': 3092,
#   'QueryQueueTimeInMillis': 145,
#   'QueryPlanningTimeInMillis': 165,
#   'ServiceProcessingTimeInMillis': 45},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Hearing_Adopt_Respondents validation

# %%
Hearing_Adopt_Respondents_count = pydb.read_sql_query("select count(*) as count from fcsq.Hearing_Adopt_Respondents")
Hearing_Adopt_Respondents_count
# Out:
#    count
# 0  94991

# %% [markdown]
# ## Adopt_App table

# %% [markdown]
# ### Drop the Adopt_App table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_App = f"""
DROP TABLE IF EXISTS fcsq.Adopt_App;
"""
pydb.start_query_execution_and_wait(drop_Adopt_App)

# clean up previous Adopt_App files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_App/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'R7J35SA697J7N2B1',
#    'HostId': '6xVb4DRSZAFUHTLT6TLaSMBUWf1NrdR4R6FbZH4HUbb4YWJ9sHPdL9YsqrQhWK6f0hF98xMr8iE=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': '6xVb4DRSZAFUHTLT6TLaSMBUWf1NrdR4R6FbZH4HUbb4YWJ9sHPdL9YsqrQhWK6f0hF98xMr8iE=',
#     'x-amz-request-id': 'R7J35SA697J7N2B1',
#     'date': 'Thu, 07 Apr 2022 11:03:04 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_App/20220406_162952_00026_69yp4_7abd92d3-ac6a-4f28-93e4-101428912974',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'b_gLDDuLOmmx8LYR5S06TulirJ2SJ.qb'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_App/20220406_162952_00026_69yp4_a912316b-ae84-4ed4-b405-6763862c38cd',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'bFpNDgJprQP.OgAQCTFtWIDfqpFmRmEg'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_App/20220406_162952_00026_69yp4_dd6db5ff-87ba-4852-b1b2-b7ea2c2dfb2c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'fkI1pJ_fB4p.t641pW6JykqUj2I.oG8k'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_App/20220406_162952_00026_69yp4_b25f11ce-09f6-44f5-83da-eaddf8b644e5',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'M5kCXeplaxmTPOMI3iHCUaEu4nE_O3mz'}]}]

# %% [markdown]
# ### Create the Adopt_App table in Athena

# %%
create_Adopt_App = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_App
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_App') AS
SELECT
  'Adoption' AS CASE_TYPE,
  Year,
  Quarter,
  'Party' AS Category,
  'Applicant' AS PARTY,
   App_Gender AS Gender,
  Representation,
  Count (*) AS Count
FROM
  fcsq.HEARING_ADOPT_APPLICANTS
WHERE 
  Representation <> '' /*A very small number of cases from 2011/12 look into whether these should be recoded as N (gender is also blank)*/
GROUP BY
  'Adoption',
  Year,
  Quarter,
  'Party',
  'Applicant',
  App_Gender,
  Representation;
"""

pydb.start_query_execution_and_wait(create_Adopt_App)
# Out:
# {'QueryExecutionId': 'ce982698-c419-4f76-bbeb-0fd7dc36eb76',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_App\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_App') AS\nSELECT\n  'Adoption' AS CASE_TYPE,\n  Year,\n  Quarter,\n  'Party' AS Category,\n  'Applicant' AS PARTY,\n   App_Gender AS Gender,\n  Representation,\n  Count (*) AS Count\nFROM\n  fcsq.HEARING_ADOPT_APPLICANTS\nWHERE \n  Representation <> '' /*A very small number of cases from 2011/12 look into whether these should be recoded as N (gender is also blank)*/\nGROUP BY\n  'Adoption',\n  Year,\n  Quarter,\n  'Party',\n  'Applicant',\n  App_Gender,\n  Representation",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/ce982698-c419-4f76-bbeb-0fd7dc36eb76'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 5, 845000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 8, 343000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2358,
#   'DataScannedInBytes': 92712,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/ce982698-c419-4f76-bbeb-0fd7dc36eb76-manifest.csv',
#   'TotalExecutionTimeInMillis': 2498,
#   'QueryQueueTimeInMillis': 106,
#   'QueryPlanningTimeInMillis': 113,
#   'ServiceProcessingTimeInMillis': 34},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adopt_App validation

# %%
Adopt_App_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_App")
Adopt_App_count
# Out:
#    count
# 0    221

# %% [markdown]
# ## Adopt_resp table

# %% [markdown]
# ### Drop the Adopt_resp table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_resp = f"""
DROP TABLE IF EXISTS fcsq.Adopt_resp;
"""
pydb.start_query_execution_and_wait(drop_Adopt_resp)

# clean up previous Adopt_resp files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_resp/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'XBYYVJPEK8CZ8TWD',
#    'HostId': 'mWf1itJkYdOcvndaSr7zsDqZgTNeRXL8epcr7jYy0puQmHzh4IS0TfohlobsRbHKDQzBVpStdRLfzQ21NdBezQ==',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'mWf1itJkYdOcvndaSr7zsDqZgTNeRXL8epcr7jYy0puQmHzh4IS0TfohlobsRbHKDQzBVpStdRLfzQ21NdBezQ==',
#     'x-amz-request-id': 'XBYYVJPEK8CZ8TWD',
#     'date': 'Thu, 07 Apr 2022 11:03:17 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_resp/20220406_163005_00056_e3ahn_9290478d-b7c8-4825-8bee-5ece6866df99',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'SvGJ6FTJgDIv4_PLMudzS5c6JRZNUwsI'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_resp/20220406_163005_00056_e3ahn_eea2230b-bdda-416a-ab33-1a1d98ebc286',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '0f0YGW0qAGhfzqLZle8xWQuYHgYkZhWq'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_resp/20220406_163005_00056_e3ahn_9f655a01-f59e-4ddc-88c7-64912e1c3b86',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ZfqO1umNdRneG5pPolVWDuvYUS4gQ38L'}]}]

# %% [markdown]
# ### Create the Adopt_resp table in Athena

# %%
create_Adopt_resp = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_resp
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_resp') AS
SELECT
  'Adoption' AS CASE_TYPE,
  Year,
  Quarter,
  'Party' AS Category,
  'Respondent' AS PARTY,
  Resp_Gender AS Gender,
  Representation,
  Count (*) AS Count
FROM
  fcsq.HEARING_ADOPT_RESPONDENTS
WHERE 
  Representation <> '' /*A very small number of cases from 2011/12 look into whether these should be recoded as N (gender is also blank)*/
GROUP BY
  'Adoption',
  Year,
  Quarter,
  'Party',
  'Applicant',
  Resp_Gender,
  Representation;
"""

pydb.start_query_execution_and_wait(create_Adopt_resp)
# Out:
# {'QueryExecutionId': 'a29956fe-fa27-4c3f-927f-e16d45d8fce8',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_resp\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_resp') AS\nSELECT\n  'Adoption' AS CASE_TYPE,\n  Year,\n  Quarter,\n  'Party' AS Category,\n  'Respondent' AS PARTY,\n  Resp_Gender AS Gender,\n  Representation,\n  Count (*) AS Count\nFROM\n  fcsq.HEARING_ADOPT_RESPONDENTS\nWHERE \n  Representation <> '' /*A very small number of cases from 2011/12 look into whether these should be recoded as N (gender is also blank)*/\nGROUP BY\n  'Adoption',\n  Year,\n  Quarter,\n  'Party',\n  'Applicant',\n  Resp_Gender,\n  Representation",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/a29956fe-fa27-4c3f-927f-e16d45d8fce8'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 18, 609000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 20, 585000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 1813,
#   'DataScannedInBytes': 97028,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/a29956fe-fa27-4c3f-927f-e16d45d8fce8-manifest.csv',
#   'TotalExecutionTimeInMillis': 1976,
#   'QueryQueueTimeInMillis': 125,
#   'QueryPlanningTimeInMillis': 137,
#   'ServiceProcessingTimeInMillis': 38},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adopt_resp validation

# %%
Adopt_resp_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_resp")
Adopt_resp_count
# Out:
#    count
# 0    235

# %% [markdown]
# ## adopt_case table

# %% [markdown]
# ### Drop the adopt_case table if it already exists and remove its data from the S3 bucket

# %%
drop_adopt_case = f"""
DROP TABLE IF EXISTS fcsq.adopt_case;
"""
pydb.start_query_execution_and_wait(drop_adopt_case)

# clean up previous adopt_case files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_case/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'BYH79DNPT7ZBPV7Q',
#    'HostId': 'nO35zb9roegTj6UakkyAIdJOFDAtzz1FuCnYFJiGyTM6JeoG7Qm8d8mEEfiY9NOy4WpsbioGjao=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'nO35zb9roegTj6UakkyAIdJOFDAtzz1FuCnYFJiGyTM6JeoG7Qm8d8mEEfiY9NOy4WpsbioGjao=',
#     'x-amz-request-id': 'BYH79DNPT7ZBPV7Q',
#     'date': 'Thu, 07 Apr 2022 11:03:30 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_case/20220406_163017_00086_hu6sp_f293ebdd-bd05-4b31-b574-cffb5dc952bf',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ADeMsAV5uoF6sz0slAKn03ZMtEFufnZX'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_case/20220406_163017_00086_hu6sp_6364cdd6-9bb0-4ff7-b49d-21497a0ef45a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '5deRKhMaa7nOxRfVR.lGdOM.cZkKPrGu'}]}]

# %% [markdown]
# ### Create the adopt_case table in Athena

# %%
create_adopt_case = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_case
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_case') AS
SELECT *,
    Count(*) as Count FROM
    (SELECT
        'Adoption' AS CASE_TYPE,
        Year,
        Quarter,
        'Cases' AS Category,
        'N/A' AS PARTY,
        'N/A' AS Gender,
        'N/A' AS Representation
    FROM
      __temp__.adopt_case_data_v3)
GROUP BY
  CASE_TYPE,
  Year,
  Quarter,
  Category,
  PARTY,
  Gender,
  Representation;
"""

pydb.start_query_execution_and_wait(create_adopt_case)
# Out:
# {'QueryExecutionId': '09aaf7ac-2515-4bbb-9f8a-b45149344096',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_case\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_case') AS\nSELECT *,\n    Count(*) as Count FROM\n    (SELECT\n        'Adoption' AS CASE_TYPE,\n        Year,\n        Quarter,\n        'Cases' AS Category,\n        'N/A' AS PARTY,\n        'N/A' AS Gender,\n        'N/A' AS Representation\n    FROM\n      mojap_de_temp_alpha_user_thomasauburnmoj.adopt_case_data_v3)\nGROUP BY\n  CASE_TYPE,\n  Year,\n  Quarter,\n  Category,\n  PARTY,\n  Gender,\n  Representation",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/09aaf7ac-2515-4bbb-9f8a-b45149344096'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 31, 506000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 33, 840000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2200,
#   'DataScannedInBytes': 45902,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/09aaf7ac-2515-4bbb-9f8a-b45149344096-manifest.csv',
#   'TotalExecutionTimeInMillis': 2334,
#   'QueryQueueTimeInMillis': 92,
#   'QueryPlanningTimeInMillis': 115,
#   'ServiceProcessingTimeInMillis': 42},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### adopt_case validation

# %%
adopt_case_count = pydb.read_sql_query("select count(*) as count from fcsq.adopt_case")
adopt_case_count
# Out:
#    count
# 0     43

# %% [markdown]
# ## Adopt_Case_Hearings table

# %% [markdown]
# ### Drop the Adopt_Case_Hearings table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_Case_Hearings = f"""
DROP TABLE IF EXISTS fcsq.Adopt_Case_Hearings;
"""
pydb.start_query_execution_and_wait(drop_Adopt_Case_Hearings)

# clean up previous Adopt_Case_Hearings files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_Case_Hearings/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'M4GYR1F2QPBPXERD',
#    'HostId': 'wZF8AMnzwSTvDnFSA7Z1AYFRXdI7F3yn03Kh3jMu+Kdo/9JSuDQD28/X33F71DlaTkveacFqnYk=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'wZF8AMnzwSTvDnFSA7Z1AYFRXdI7F3yn03Kh3jMu+Kdo/9JSuDQD28/X33F71DlaTkveacFqnYk=',
#     'x-amz-request-id': 'M4GYR1F2QPBPXERD',
#     'date': 'Thu, 07 Apr 2022 11:03:43 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_Case_Hearings/20220406_163038_00010_hbsqe_bd6a1017-064b-4ee7-8f93-59f9231660f9',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '8xcAg5.NZjRiSfW0LCphsWo_xS6xFEyG'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Case_Hearings/20220406_163038_00010_hbsqe_ec57a0a3-a9f5-4d65-9718-a299fb979505',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '6j4F4KcDZuhYzerNH8lD5XFW88YXlLqD'}]}]

# %% [markdown]
# ### Create the Adopt_Case_Hearings table in Athena

# %%
create_hearing_adopt_case =f"""
SELECT DISTINCT Year, Quarter, Case_Number
FROM fcsq.HEARING_ADOPT_Applicants;
"""

pydb.create_temp_table(create_hearing_adopt_case,'hearing_adopt_case')



create_Adopt_Case_Hearings = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_Case_Hearings
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Case_Hearings') AS
SELECT *, Count(*) as Count FROM
    (SELECT
      'Adoption' AS CASE_TYPE,
      Year,
      Quarter,
      'Cases with a hearing' AS Category,
      'N/A' AS PARTY,
      'N/A' AS Gender,
      'N/A' AS Representation
    FROM
      __temp__.Hearing_ADOPT_Case)
GROUP BY
  CASE_TYPE,
  Year,
  Quarter,
  Category,
  PARTY,
  Gender,
  Representation;
"""

pydb.start_query_execution_and_wait(create_Adopt_Case_Hearings)
# Out:
# {'QueryExecutionId': 'e2a53f59-f9a9-4808-9085-23edc4d130fc',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_Case_Hearings\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Case_Hearings') AS\nSELECT *, Count(*) as Count FROM\n    (SELECT\n      'Adoption' AS CASE_TYPE,\n      Year,\n      Quarter,\n      'Cases with a hearing' AS Category,\n      'N/A' AS PARTY,\n      'N/A' AS Gender,\n      'N/A' AS Representation\n    FROM\n      mojap_de_temp_alpha_user_thomasauburnmoj.Hearing_ADOPT_Case)\nGROUP BY\n  CASE_TYPE,\n  Year,\n  Quarter,\n  Category,\n  PARTY,\n  Gender,\n  Representation",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/e2a53f59-f9a9-4808-9085-23edc4d130fc'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 52, 991000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 3, 55, 90000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 1804,
#   'DataScannedInBytes': 42003,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/e2a53f59-f9a9-4808-9085-23edc4d130fc-manifest.csv',
#   'TotalExecutionTimeInMillis': 2099,
#   'QueryQueueTimeInMillis': 194,
#   'QueryPlanningTimeInMillis': 227,
#   'ServiceProcessingTimeInMillis': 101},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adopt_Case_Hearings validation

# %%
Adopt_Case_Hearings_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_Case_Hearings")
Adopt_Case_Hearings_count
# Out:
#    count
# 0     43

# %% [markdown]
# ## Adoption table

# %% [markdown]
# ### Drop the Adoption table if it already exists and remove its data from the S3 bucket

# %%
drop_Adoption = f"""
DROP TABLE IF EXISTS fcsq.Adoption;
"""
pydb.start_query_execution_and_wait(drop_Adoption)

# clean up previous Adoption files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adoption/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'A5HSZN8ZDWSB31X7',
#    'HostId': 'CcpqdTSb+jgRba6GVZkDxJNGnrzUjyLLhv5r4dhHJDmes5phMr5ofy58DzSnOVdGqqrb6W3xumo=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'CcpqdTSb+jgRba6GVZkDxJNGnrzUjyLLhv5r4dhHJDmes5phMr5ofy58DzSnOVdGqqrb6W3xumo=',
#     'x-amz-request-id': 'A5HSZN8ZDWSB31X7',
#     'date': 'Thu, 07 Apr 2022 11:04:04 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adoption/20220406_163051_00074_neckb_91ac0d6d-4a2d-4509-9f90-95b2f5e4e8d4',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Ec3XpbLfzMgQM7uA.oVhbjBdPw3D2k26'},
#    {'Key': 'fcsq_processing/Adoption/Adoption/20220406_163051_00074_neckb_324cb459-dbe3-4b89-8162-d92cb27cc80c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'pOOwEfotdhrTRekg_AxX9kMVanua7rGZ'},
#    {'Key': 'fcsq_processing/Adoption/Adoption/20220406_163051_00074_neckb_cabc8273-bbcb-4335-b4bf-c5c488d2abfd',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '7J1lk59vtdmDqFrtJo4NqfJWdTfIgbuR'},
#    {'Key': 'fcsq_processing/Adoption/Adoption/20220406_163051_00074_neckb_bd45d899-2074-421f-805e-31dffce998a7',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'e_UoPHB8wT30u4dlNUGuBsNzJoPVvBx.'}]}]

# %% [markdown]
# ### Create the Adoption table in Athena

# %%
create_Adoption = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adoption
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adoption') AS
SELECT
  *
FROM
 fcsq.ADOPT_APP
UNION ALL
SELECT
  *
FROM
  fcsq.ADOPT_RESP
UNION ALL
SELECT
  *
FROM
  fcsq.ADOPT_CASE
UNION ALL
SELECT
  *
FROM
  fcsq.ADOPT_CASE_HEARINGS;
"""

pydb.start_query_execution_and_wait(create_Adoption)
# Out:
# {'QueryExecutionId': '300b1a7d-8f7c-4eb5-aed5-ff5ea81da968',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adoption\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adoption') AS\nSELECT\n  *\nFROM\n fcsq.ADOPT_APP\nUNION ALL\nSELECT\n  *\nFROM\n  fcsq.ADOPT_RESP\nUNION ALL\nSELECT\n  *\nFROM\n  fcsq.ADOPT_CASE\nUNION ALL\nSELECT\n  *\nFROM\n  fcsq.ADOPT_CASE_HEARINGS",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/300b1a7d-8f7c-4eb5-aed5-ff5ea81da968'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 4, 5, 842000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 4, 8, 125000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2129,
#   'DataScannedInBytes': 12209,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/300b1a7d-8f7c-4eb5-aed5-ff5ea81da968-manifest.csv',
#   'TotalExecutionTimeInMillis': 2283,
#   'QueryQueueTimeInMillis': 95,
#   'QueryPlanningTimeInMillis': 147,
#   'ServiceProcessingTimeInMillis': 59},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adoption validation

# %%
Adoption_count = pydb.read_sql_query("select count(*) as count from fcsq.Adoption")
Adoption_count
# Out:
#    count
# 0    542

# %% [markdown]
# ## Applicant_representation table

# %% [markdown]
# ### Drop the Applicant_representation table if it already exists and remove its data from the S3 bucket

# %%
drop_Applicant_representation = f"""
DROP TABLE IF EXISTS fcsq.Applicant_representation;
"""
pydb.start_query_execution_and_wait(drop_Applicant_representation)

# clean up previous Applicant_representation files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Applicant_representation/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'BP207EFQY3N0320D',
#    'HostId': 'Q/fhtAxEzQEf51MvQ9sHXHO2zxrk1cNzBkMOU9BnAcaVDNju/UC3gXCI7r/oskHfJU3g77Pt4UA=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'Q/fhtAxEzQEf51MvQ9sHXHO2zxrk1cNzBkMOU9BnAcaVDNju/UC3gXCI7r/oskHfJU3g77Pt4UA=',
#     'x-amz-request-id': 'BP207EFQY3N0320D',
#     'date': 'Thu, 07 Apr 2022 11:04:18 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_f0252942-96fc-40ea-92b5-630365a0cb53',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '6ip2VXyJvrtl62BkahxllXNEKo4ZGgXt'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_4c7a79b5-6c62-4fc9-a2d8-69d47bca5cf5',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'TFnD8EU8Mpq2ej1Gw4FaB6zgTiQlJt_X'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_5c845119-069b-4c9b-92b6-51cafe02f83a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'UEidx2pyBbQE2ceDoWK6jxdWvyY6ntF1'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_e68ffa4f-732a-4a0b-9bed-5ba73ae405df',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'SqBBI01D3jnO4TokT1VgEyPrnZpq67is'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_126bc395-bda2-481a-b5a8-995162f3e94d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'UQs1G6U1wp761Pe4FX6CxOndltVdV3nO'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_66deccb8-469c-4967-80ce-d070a995687d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'FFycyFOp9CV0xw0IwHZL5Cv3qGtF9DyG'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_62974f51-3e5e-4775-80b1-af059df9c332',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'XjlB6UGZZRoJFGGzUZeefsHGrTz6lloz'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_d444e7b3-12da-4560-b343-4daa92e44f3a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'PnqEh8DTm15JL.2.z0v88gDM2FnNN3Cd'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_f7c921f9-41fe-49cc-aa60-db81a338f5c0',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'onkSfx5r_FfmoL0lGb3_qC3NTOsCEYO3'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_fc5f8bd9-37f6-418f-8736-f0d913e81d8a',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '42s1Jcnrp.lrdZclCg4k8R2CzH8HdU3U'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_02fd5508-100c-4034-8b78-e2e8e614fe4d',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '9ERt7BmzYMRmHBHEZsXqghTeRgJMMb9Y'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_9c00b8e8-c5cd-41b2-ad89-709ed3d8beba',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'y1ZpMa_1dJ2SYYZc1_LKuamT6LXdZhU9'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_348d994b-712a-445f-9fc9-7d7559782b11',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'uHj6TjsN0Irr_KLKxggFlHbbAyAQWx2_'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_55ca0597-a909-440b-8416-1f1573497f6f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'wkdGXr5jgHAhCVwH1PKPt43EWqhMNP3N'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_a6dbdc17-8605-4f76-8f99-b61c21ccaca5',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'OrO1p1d3fFfKQiqYUYT9asYOjZZImohY'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_41591144-37ab-4f58-a1e5-e85467b84ec2',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'KUC5x9IQi6szXsHuxjQwPJJLC.2Qmumx'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_4cdffa73-1e47-416d-b2af-2dd6f5117afa',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'D.rCMs8T1i2SUmdyIqiFWckQSVnvclgG'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_62f4f251-1962-4e37-8987-ec1002a0bf09',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Dkdmp70_K3kMDgYU1TXMByhmYh1wAtTS'},
#    {'Key': 'fcsq_processing/Adoption/Applicant_representation/20220406_163127_00086_3wfqx_8c3379e2-21ed-4387-9a0e-e8b924fd31da',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'NCLsrEN2yqpYA6hvY_0h7waLdDLIy53N'}]}]

# %% [markdown]
# ### Create the Applicant_representation table in Athena

# %%
create_applicants_1 = f"""
SELECT Distinct t1.Case_Number, t1.Party, MAX(t1.Representative_Role) as Max_Rep_Role
FROM fcsq.Adopt_Applicant_Info t1
Group by Case_Number, Party;
"""

pydb.create_temp_table(create_applicants_1,'applicants_1')

create_applicants_2 = f"""
SELECT  t1.*,
case when Max_Rep_Role IS NULL then 0
else 1
end as Rep_IND
FROM __temp__.Applicants_1 t1;
"""
pydb.create_temp_table(create_applicants_2,'applicants_2')

create_applicants_3 = f"""
SELECT Distinct t1.Case_Number,
Count(t1.Party) as CountOfParty,
SUM(t1.Rep_Ind) as SumOfRep_IND
FROM __temp__.Applicants_2 t1
Group by Case_Number;
"""
pydb.create_temp_table(create_applicants_3,'applicants_3')

create_Applicant_representation = f"""
CREATE TABLE IF NOT EXISTS fcsq.Applicant_representation
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Applicant_representation') AS
SELECT t1.Case_Number,
t1.CountOfParty,
t1.SumOfRep_IND,
CASE WHEN t1.SumOfRep_Ind > t1.CountOfParty then 'Error'
WHEN t1.SumOfRep_Ind = t1.CountOfParty then 'All'
WHEN t1.SumOfRep_Ind =0 then 'None' else 'Some'  end as App_Rep_Cat
FROM __temp__.Applicants_3 t1;
"""

pydb.start_query_execution_and_wait(create_Applicant_representation)
# Out:
# {'QueryExecutionId': '7b67fc70-8eaa-4168-8598-c772b52e9610',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Applicant_representation\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Applicant_representation') AS\nSELECT t1.Case_Number,\nt1.CountOfParty,\nt1.SumOfRep_IND,\nCASE WHEN t1.SumOfRep_Ind > t1.CountOfParty then 'Error'\nWHEN t1.SumOfRep_Ind = t1.CountOfParty then 'All'\nWHEN t1.SumOfRep_Ind =0 then 'None' else 'Some'  end as App_Rep_Cat\nFROM mojap_de_temp_alpha_user_thomasauburnmoj.Applicants_3 t1",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/7b67fc70-8eaa-4168-8598-c772b52e9610'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 4, 44, 331000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 4, 46, 831000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2345,
#   'DataScannedInBytes': 16268774,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/7b67fc70-8eaa-4168-8598-c772b52e9610-manifest.csv',
#   'TotalExecutionTimeInMillis': 2500,
#   'QueryQueueTimeInMillis': 117,
#   'QueryPlanningTimeInMillis': 136,
#   'ServiceProcessingTimeInMillis': 38},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Applicant_representation validation

# %%
Applicant_representation_count = pydb.read_sql_query("select count(*) as count from fcsq.Applicant_representation")
Applicant_representation_count
# Out:
#      count
# 0  1861318

# %% [markdown]
# ## Respondent_Representation table

# %% [markdown]
# ### Drop the Respondent_Representation table if it already exists and remove its data from the S3 bucket

# %%
drop_Respondent_Representation = f"""
DROP TABLE IF EXISTS fcsq.Respondent_Representation;
"""
pydb.start_query_execution_and_wait(drop_Respondent_Representation)

# clean up previous Respondent_Representation files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Respondent_Representation/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'D9WTM2NNTV3JK8CY',
#    'HostId': 'ZFGpNeYbxvlarpnPoGR/hgjo0Uyh9F4+OfWlXTmMPQhLYkzpQfAv5GnhQ4VaZnlcKVhxD528T2VyD+qUkHfEYg==',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'ZFGpNeYbxvlarpnPoGR/hgjo0Uyh9F4+OfWlXTmMPQhLYkzpQfAv5GnhQ4VaZnlcKVhxD528T2VyD+qUkHfEYg==',
#     'x-amz-request-id': 'D9WTM2NNTV3JK8CY',
#     'date': 'Thu, 07 Apr 2022 11:04:56 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_7b77400a-9bf6-4d36-840b-4d1f2890684f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'OqzQ_wiwYXvPGnHJtikpu_zvOlqzg3e6'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_fe9fadc1-dda6-40ea-be23-a9b6fd4cb9e8',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'uH7YzbsS7bMg2hnnwjXeYlJm8SrPR.bZ'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_27108b98-c42a-446d-bfac-6dc6517c6a37',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '0Bj78Tq6YYODdl1HaPFK0OJxr1uDtKbU'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_ce436c6e-abf5-4a32-9a0b-882d419cb54b',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'kEQMkGZRSgTqeettlOWBSvk8CgKWb.lI'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_dde9d241-6b77-4a8b-a2c4-327db9b141b4',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'vM9HtACrvFLRISAgbUN3bRez2MhOjM1a'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_2605f881-8631-4070-a5f2-1dd080a5c171',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'Awyl8SFaeRP8YYM4.eiUZYSEE1oN25Iw'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_26955bda-dc1b-40d0-b77a-c10342161f81',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'IGn9z9h77_uAT3nx0b7e4WlwWWLcQK27'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_699aea8b-21ee-4c87-a14e-1c34db25b2ca',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'pmtjtb4OStAYGg5wN9hf4p67VVt2duFG'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_5f91807f-952a-4f3f-a6bf-37c7fc0e72e1',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'aHOtStmMgwH9OJFe9RyBWg10K8A5QSPP'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_9b7ab18f-982c-4786-9c2a-7badd59cf15e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'UOgyT8mDTWFu6A7JHaAFWbKCRPT1XNh5'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_dd207f53-8d30-492d-82d7-84f8bac781fa',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'cS_kwSh0mfomjPGH4asF2xfKn16dODwE'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_df833477-9e5b-444c-b5c2-0c00e5560453',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'HmqbBCKyF5UtXE96JjKDKvmDI.8B9UoD'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_e3ff20d7-968d-4d18-a1da-42b3596133b6',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'ZZigDNQ8fnN3VtAj79begjy7Yswc969Q'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_ae9dc44d-7aad-4126-a015-e742ea39e7f3',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'M_rK8rd24OOijH3tgbFqy0FNQQCNL9qV'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_7443153d-6f97-4511-b25e-8818e1fbec26',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'jqO9sPYjo_BjmwPKBJSk940srCGPIk7u'},
#    {'Key': 'fcsq_processing/Adoption/Respondent_Representation/20220406_163205_00088_vbfvk_f829b401-379d-4a69-a483-c6523ec6530c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '8eoQpNyTgUEzvjWyTAx9uwQy9HZ01oDY'}]}]

# %% [markdown]
# ### Create the Respondent_Representation table in Athena

# %%
create_respondents_1 = f"""
SELECT Distinct t1.Case_Number, t1.Party, MAX(t1.Representative_Role) as Max_Rep_Role
FROM fcsq.Adopt_Respondent_Info t1
Group by Case_Number, Party;
"""

pydb.create_temp_table(create_respondents_1,'respondents_1')

create_respondents_2 = f"""
SELECT  t1.*,
case when Max_Rep_Role IS NULL then 0
else 1
end as Rep_IND
FROM __temp__.respondents_1 t1;
"""
pydb.create_temp_table(create_respondents_2,'respondents_2')

create_respondents_3 = f"""
SELECT Distinct t1.Case_Number,
Count(t1.Party) as CountOfParty,
SUM(t1.Rep_Ind) as SumOfRep_IND
FROM __temp__.respondents_2 t1
Group by Case_Number;
"""
pydb.create_temp_table(create_respondents_3,'respondents_3')

create_Respondent_Representation = f"""
CREATE TABLE IF NOT EXISTS fcsq.Respondent_Representation
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Respondent_Representation') AS
SELECT t1.Case_Number,
t1.CountOfParty,
t1.SumOfRep_IND,
CASE WHEN t1.SumOfRep_Ind > t1.CountOfParty then 'Error'
WHEN t1.SumOfRep_Ind = t1.CountOfParty then 'All'
WHEN t1.SumOfRep_Ind =0 then 'None' else 'Some'  end as Res_Rep_Cat
FROM __temp__.Respondents_3 t1
"""

pydb.start_query_execution_and_wait(create_Respondent_Representation)
# Out:
# {'QueryExecutionId': 'ef10ba04-6353-4648-b38c-4c9c05b13d0c',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Respondent_Representation\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Respondent_Representation') AS\nSELECT t1.Case_Number,\nt1.CountOfParty,\nt1.SumOfRep_IND,\nCASE WHEN t1.SumOfRep_Ind > t1.CountOfParty then 'Error'\nWHEN t1.SumOfRep_Ind = t1.CountOfParty then 'All'\nWHEN t1.SumOfRep_Ind =0 then 'None' else 'Some'  end as Res_Rep_Cat\nFROM mojap_de_temp_alpha_user_thomasauburnmoj.Respondents_3 t1",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/ef10ba04-6353-4648-b38c-4c9c05b13d0c'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 5, 22, 480000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 5, 24, 927000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2270,
#   'DataScannedInBytes': 16527739,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/ef10ba04-6353-4648-b38c-4c9c05b13d0c-manifest.csv',
#   'TotalExecutionTimeInMillis': 2447,
#   'QueryQueueTimeInMillis': 127,
#   'QueryPlanningTimeInMillis': 128,
#   'ServiceProcessingTimeInMillis': 50},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Respondent_Representation validation

# %%
Respondent_Representation_count = pydb.read_sql_query("select count(*) as count from fcsq.Respondent_Representation")
Respondent_Representation_count
# Out:
#      count
# 0  1854596

# %% [markdown]
# ## Adopt_Disposals_Final table

# %%
create_ADOPT_APP_AND_ORDERS_WITH_REP = f"""
SELECT t1.*,
t2.APP_REP_CAT, 
t3.RES_REP_CAT
FROM fcsq.ADOPT_APPS_AND_ORDERS_MATCH AS t1
LEFT JOIN fcsq.Applicant_Representation AS t2 ON (t1.CASE_NUMBER = t2.CASE_NUMBER)
LEFT JOIN fcsq.RESPONDENT_REPRESENTATION as t3 ON t1.CASE_NUMBER = t3.CASE_NUMBER;
"""
pydb.create_temp_table(create_ADOPT_APP_AND_ORDERS_WITH_REP,'ADOPT_APP_AND_ORDERS_WITH_REP')

# %%
pydb.read_sql_query("SELECT Count(*) as COUNT from __temp__.adopt_app_and_orders_with_rep")
# Out:
#     count
# 0  147875

# %%
create_Adopt_Disposals_Final = f"""
SELECT t1.*,
cast(t1.Year as varchar(3)) || '-Q' || cast(t1.quarter as varchar(3)) AS Quarter2, 
case when (t1.APP_REP_CAT Is Null Or t1.RES_REP_CAT Is Null)  then '5 Unknown'
    when t1.APP_REP_CAT='None' and t1.RES_REP_CAT ='None' then '4 Neither'
    when t1.APP_REP_CAT='None' and t1.RES_REP_CAT != 'None' then '3 Respondent Only'
    when t1.APP_REP_CAT != 'None' and t1.RES_REP_CAT = 'None' then '2 Applicant Only'
Else '1 Both'
End AS REP_CAT

FROM __temp__.ADOPT_APP_AND_ORDERS_WITH_REP AS t1 LEFT JOIN (SELECT * FROM {database}.courts_mv WHERE {database}.courts_mv.mojap_snapshot_date = date '{snapshot_date}')
AS t2 
ON t1.DSP_COURT = cast(t2.Code as varchar(3));

"""

pydb.create_temp_table(create_Adopt_Disposals_Final,'Adopt_Disposals_Final')

"""
Missed out these columns for now:

t2.Region_Pre2014, 
t2.Region,
Case when t1.YEAR < 2014 then t2.Region_Pre2014
Else t2.Region
End As Final_Region

"""

create_Adopt_Disposals_Final_2 = f"""
SELECT *
FROM __temp__.ADOPT_DISPOSALS_FINAL
WHERE adoption = 'Adoption';
"""

pydb.create_temp_table(create_Adopt_Disposals_Final_2,'Adopt_Disposals_Final_2')

# %% [markdown]
# #### Adopt_Disposals_Final validation

# %%
Adopt_Disposals_Final_count = pydb.read_sql_query("select count(*) as count from __temp__.Adopt_Disposals_Final_2")
Adopt_Disposals_Final_count
# Out:
#    count
# 0  82011

# %% [markdown]
# ## Adopt_Quarterly table

# %% [markdown]
# ### Drop the Adopt_Quarterly table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_Quarterly = f"""
DROP TABLE IF EXISTS fcsq.Adopt_Quarterly;
"""
pydb.start_query_execution_and_wait(drop_Adopt_Quarterly)

# clean up previous Adopt_Quarterly files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_Quarterly/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'S3KRYH3J7EX13D7T',
#    'HostId': 'AIAoVI+MaDLDXi8t1ZIqKAS/vXk9ngEakTjfVoJmT0WqnDG7jpb6XtAfpwrYDYVclpHFyUtV3Ho=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'AIAoVI+MaDLDXi8t1ZIqKAS/vXk9ngEakTjfVoJmT0WqnDG7jpb6XtAfpwrYDYVclpHFyUtV3Ho=',
#     'x-amz-request-id': 'S3KRYH3J7EX13D7T',
#     'date': 'Thu, 07 Apr 2022 11:06:11 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_Quarterly/20220406_163255_00048_6mumg_c9fe2920-8ad1-40bd-9c4d-a81680d2ae62',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'n46Ur2YAGbgUpYSgIQjoS1gGyigO1I5r'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Quarterly/20220406_163255_00048_6mumg_52a69ac9-3da3-44ba-8ead-c826bd93625f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'CTOgGo.vkH_KrkbL_8uYYkIaMrxgSn8h'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Quarterly/20220406_163255_00048_6mumg_748e37e4-df6a-45cb-9ad6-c5ec3ed6ad32',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'si2NMv_c896Iz_4yiVI5.H2AWwZOwdla'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Quarterly/20220406_163255_00048_6mumg_9847c9f3-7bfd-4281-8d3e-dabaf06a405e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'kpt4EeC4szNT254qAhIVIxKPYzPuSKtf'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Quarterly/20220406_163255_00048_6mumg_d11a604c-b563-4eef-9ab3-6001d4325e3c',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'j53sM4eVGWiLmdv2IiCuwIY1sm2TZ41b'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Quarterly/20220406_163255_00048_6mumg_6f162e6e-5ef3-496e-88a0-add4c5c6fc82',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'BPx0Ns_4n8Y9yfLSMt8n7rmkB8iKgHYF'}]}]

# %% [markdown]
# ### Create the Adopt_Quarterly table in Athena

# %%
create_Adopt_Quarterly = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_Quarterly
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Quarterly') AS
SELECT DISTINCT
        'Adoption' as type,
        year,
        'Q' || cast(quarter as varchar(3)) AS quarter,
        rep_cat,
        count(*) as n,
        avg(wait_weeks) as mean
    FROM 
        __temp__.ADOPT_DISPOSALS_FINAL_2
    WHERE year > 2010 
    AND quarter2 <> '2021-Q4'
    AND adoption='Adoption'
GROUP BY
    year,
    quarter,
    rep_cat
    
UNION ALL
SELECT DISTINCT
        'Adoption' as type,
        year,
        'Q' || cast(quarter as varchar(3)) AS quarter,
        'All' as rep_cat,
        count(*) as n,
        avg(wait_weeks) as mean
    FROM 
        __temp__.ADOPT_DISPOSALS_FINAL_2
    WHERE year > 2010 
    AND quarter2 <> '2021-Q4'
    AND adoption='Adoption'
GROUP BY
    year,
    quarter
"""


testA = f"""
SELECT * FROM __temp__.ADOPT_DISPOSALS_FINAL_2 WHERE year=2015 AND quarter = 3;
"""
testB = f"""
SELECT * FROM fcsq.Adopt_Quarterly WHERE year=2015 AND quarter = 'Q3' ORDER BY rep_cat
"""

pydb.start_query_execution_and_wait(create_Adopt_Quarterly)
#pydb.read_sql_query(testA)
pydb.read_sql_query(testB)
# Out:
#        type  year quarter            rep_cat     n       mean
# 0  Adoption  2015      Q3             1 Both    16  28.312500
# 1  Adoption  2015      Q3   2 Applicant Only    59  20.949153
# 2  Adoption  2015      Q3  3 Respondent Only    44  27.613636
# 3  Adoption  2015      Q3          4 Neither  1325  14.772830
# 4  Adoption  2015      Q3          5 Unknown    15  20.133333
# 5  Adoption  2015      Q3                All  1459  15.613434

# %% [markdown]
# #### Adopt_Quarterly validation

# %%
Adopt_Quarterly_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_Quarterly")
Adopt_Quarterly_count

pydb.read_sql_query("select * from fcsq.Adopt_Quarterly WHERE year = 2014 AND quarter = \'Q2' ORDER BY rep_cat")
# Out:
#        type  year quarter            rep_cat     n       mean
# 0  Adoption  2014      Q2             1 Both    17  35.058824
# 1  Adoption  2014      Q2   2 Applicant Only    58  23.672414
# 2  Adoption  2014      Q2  3 Respondent Only    45  24.444444
# 3  Adoption  2014      Q2          4 Neither  1580  14.211392
# 4  Adoption  2014      Q2          5 Unknown    15  11.800000
# 5  Adoption  2014      Q2                All  1715  14.985423

# %% [markdown]
# ## Adopt_Annual table

# %% [markdown]
# ### Drop the Adopt_Annual table if it already exists and remove its data from the S3 bucket

# %%
drop_Adopt_Annual = f"""
DROP TABLE IF EXISTS fcsq.Adopt_Annual;
"""
pydb.start_query_execution_and_wait(drop_Adopt_Annual)

# clean up previous Adopt_Annual files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/Adopt_Annual/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '218WQMT2C56V9PG7',
#    'HostId': 'L7Te+uGOip3m4jMQN3/H8gudaU5bDI2QRcuEsHvexEMLkUnJltc2ZaY//Eq/nsIW5cIMfibi94g=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'L7Te+uGOip3m4jMQN3/H8gudaU5bDI2QRcuEsHvexEMLkUnJltc2ZaY//Eq/nsIW5cIMfibi94g=',
#     'x-amz-request-id': '218WQMT2C56V9PG7',
#     'date': 'Thu, 07 Apr 2022 11:06:35 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/Adopt_Annual/20220406_163318_00092_9fx83_077dec32-8ed5-4e00-8f3d-7c2a3cad494f',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'qXOAeNcndjFjocuXNOt.YUljmOMNsSmg'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Annual/20220406_163318_00092_9fx83_298b0f7f-f431-4cf7-a9eb-28240b7843d8',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'NSnWWGkiOdGdEZiynp7OMmEDb8zXtaZV'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Annual/20220406_163318_00092_9fx83_c864d929-159f-448d-acb7-4008ef41802e',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': '4vTljw57ilvsMRFlOqLWIAn0ZJ2rp.g4'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Annual/20220406_163318_00092_9fx83_2ea51ea1-0155-4df2-a72e-971c83535bf7',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'zwRJaEYk72KVDsfDx9fIEBvmMCL7Hbux'},
#    {'Key': 'fcsq_processing/Adoption/Adopt_Annual/20220406_163318_00092_9fx83_0fa56d0b-2b5f-4614-b699-9f92b6806eb4',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'qWjoSb3SHzh0YvCTZvgZTTdYDj0locJ.'}]}]

# %% [markdown]
# ### Create the Adopt_Annual table in Athena

# %%
create_Adopt_Annual = f"""
CREATE TABLE IF NOT EXISTS fcsq.Adopt_Annual
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Annual') AS
SELECT DISTINCT
        'Adoption' as type,
        year,
        'N/A' as quarter,
        rep_cat,
        count(*) as n,
        avg(wait_weeks) as mean
    FROM 
        __temp__.ADOPT_DISPOSALS_FINAL_2
    WHERE year > 2010 
    AND year < 2021
    AND adoption='Adoption'
GROUP BY
    year,
    rep_cat
    
UNION ALL
SELECT DISTINCT
        'Adoption' as type,
        year,
        'N/A' as quarter,
        'All' as rep_cat,
        count(*) as n,
        avg(wait_weeks) as mean
    FROM 
        __temp__.ADOPT_DISPOSALS_FINAL_2
    WHERE year > 2010 
    AND year < 2021
    AND adoption='Adoption'
GROUP BY
    year
"""

pydb.start_query_execution_and_wait(create_Adopt_Annual)
# Out:
# {'QueryExecutionId': '4acbd691-ac97-4198-ad27-0f242c4121b6',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.Adopt_Annual\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/Adopt_Annual') AS\nSELECT DISTINCT\n        'Adoption' as type,\n        year,\n        'N/A' as quarter,\n        rep_cat,\n        count(*) as n,\n        avg(wait_weeks) as mean\n    FROM \n        mojap_de_temp_alpha_user_thomasauburnmoj.ADOPT_DISPOSALS_FINAL_2\n    WHERE year > 2010 \n    AND year < 2021\n    AND adoption='Adoption'\nGROUP BY\n    year,\n    rep_cat\n    \nUNION ALL\nSELECT DISTINCT\n        'Adoption' as type,\n        year,\n        'N/A' as quarter,\n        'All' as rep_cat,\n        count(*) as n,\n        avg(wait_weeks) as mean\n    FROM \n        mojap_de_temp_alpha_user_thomasauburnmoj.ADOPT_DISPOSALS_FINAL_2\n    WHERE year > 2010 \n    AND year < 2021\n    AND adoption='Adoption'\nGROUP BY\n    year",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/4acbd691-ac97-4198-ad27-0f242c4121b6'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 6, 37, 28000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 6, 39, 103000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 1926,
#   'DataScannedInBytes': 407566,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/4acbd691-ac97-4198-ad27-0f242c4121b6-manifest.csv',
#   'TotalExecutionTimeInMillis': 2075,
#   'QueryQueueTimeInMillis': 105,
#   'QueryPlanningTimeInMillis': 148,
#   'ServiceProcessingTimeInMillis': 44},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### Adopt_Annual validation

# %%
Adopt_Annual_count = pydb.read_sql_query("select count(*) as count from fcsq.Adopt_Annual")
Adopt_Annual_count
# Out:
#    count
# 0     60

# %%
df = pydb.read_sql_query("SELECT * FROM fcsq.Adoption")
df.to_csv(path_or_buf = 's3://alpha-family-data/CSVs/Adoption_legrep.csv',index=False)
#df.to_excel('adoption.xlsx')

# %%
df = pydb.read_sql_query("SELECT * FROM fcsq.Adopt_Annual UNION ALL SELECT * FROM fcsq.Adopt_Quarterly ORDER BY type,year,quarter,rep_cat")
df.to_csv(path_or_buf = '~/FCSQ_data/timeliness.csv',index=False)

# %% [markdown]
# ## adopt_timeliness_combined table

# %% [markdown]
# ### Drop the adopt_timeliness_combined table if it already exists and remove its data from the S3 bucket

# %%
drop_adopt_timeliness_combined = f"""
DROP TABLE IF EXISTS fcsq.adopt_timeliness_combined;
"""
pydb.start_query_execution_and_wait(drop_adopt_timeliness_combined)

# clean up previous adopt_timeliness_combined files
bucket.objects.filter(Prefix="fcsq_processing/Adoption/adopt_timeliness_combined/").delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'H4GSCFWHYXMK14DN',
#    'HostId': 'Tm4eeYQXxiv35JOAIqxpEcqQzsPBQKinvFxg012J3n5uYFZor9+JV6uMIUoYt46uj61KJLCyhqQ=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'Tm4eeYQXxiv35JOAIqxpEcqQzsPBQKinvFxg012J3n5uYFZor9+JV6uMIUoYt46uj61KJLCyhqQ=',
#     'x-amz-request-id': 'H4GSCFWHYXMK14DN',
#     'date': 'Thu, 07 Apr 2022 11:07:01 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'fcsq_processing/Adoption/adopt_timeliness_combined/20220406_163345_00098_w2gwr_641c9532-49dc-4cd1-a80b-a588edb94abd',
#     'DeleteMarker': True,
#     'DeleteMarkerVersionId': 'aBhgNr3OHc3wLVoX6bsv1R7BUYCoi26S'}]}]

# %% [markdown]
# ### Create the adopt_timeliness_combined table in Athena

# %%
create_adopt_timeliness_combined = f"""
CREATE TABLE IF NOT EXISTS fcsq.adopt_timeliness_combined
WITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/adopt_timeliness_combined') AS
SELECT * FROM fcsq.Adopt_Annual 
UNION ALL 
SELECT * FROM fcsq.Adopt_Quarterly ORDER BY type,year,quarter,rep_cat
"""

pydb.start_query_execution_and_wait(create_adopt_timeliness_combined)
# Out:
# {'QueryExecutionId': 'f4df8bb6-3f5a-4e4b-bdf0-27c73f102519',
#  'Query': "CREATE TABLE IF NOT EXISTS fcsq.adopt_timeliness_combined\nWITH (format = 'PARQUET', external_location = 's3://alpha-family-data/fcsq_processing/Adoption/adopt_timeliness_combined') AS\nSELECT * FROM fcsq.Adopt_Annual \nUNION ALL \nSELECT * FROM fcsq.Adopt_Quarterly ORDER BY type,year,quarter,rep_cat",
#  'StatementType': 'DDL',
#  'ResultConfiguration': {'OutputLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/f4df8bb6-3f5a-4e4b-bdf0-27c73f102519'},
#  'QueryExecutionContext': {},
#  'Status': {'State': 'SUCCEEDED',
#   'SubmissionDateTime': datetime.datetime(2022, 4, 7, 11, 7, 2, 742000, tzinfo=tzlocal()),
#   'CompletionDateTime': datetime.datetime(2022, 4, 7, 11, 7, 4, 973000, tzinfo=tzlocal())},
#  'Statistics': {'EngineExecutionTimeInMillis': 2062,
#   'DataScannedInBytes': 7823,
#   'DataManifestLocation': 's3://aws-athena-query-results-593291632749-eu-west-1/tables/f4df8bb6-3f5a-4e4b-bdf0-27c73f102519-manifest.csv',
#   'TotalExecutionTimeInMillis': 2231,
#   'QueryQueueTimeInMillis': 158,
#   'ServiceProcessingTimeInMillis': 11},
#  'WorkGroup': 'primary',
#  'EngineVersion': {'SelectedEngineVersion': 'Athena engine version 2',
#   'EffectiveEngineVersion': 'Athena engine version 2'}}

# %% [markdown]
# #### adopt_timeliness_combined validation

# %%
adopt_timeliness_combined_count = pydb.read_sql_query("select count(*) as count from fcsq.adopt_timeliness_combined")
adopt_timeliness_combined_count
# Out:
#    count
# 0    318

# %%
df = pydb.read_sql_query("SELECT * FROM fcsq.adopt_timeliness_combined WHERE (Year<2021 OR Quarter!='Q3') AND (Year<2021 OR Quarter!='Q2')")
df = df.pivot_table(index=['type','year','quarter'],columns=['rep_cat'],values = ['n','mean'],aggfunc=sum, fill_value=0).swaplevel(axis=1).sort_index(axis=1)
df
# Out:
# rep_cat               1 Both                 2 Applicant Only       3 Respondent Only      4 Neither               5 Unknown              All
#                                    mean    n              mean    n              mean    n              mean     n              mean    n              mean     n
# type     year quarter
# Adoption 2011 N/A             28.560000  100         18.811024  254         18.597765  179         15.139358  4083         14.797688  173         15.731259  4789
#               Q1              31.761905   21         21.619048   63         20.225000   40         15.391906   939         14.319149   47         16.183784  1110
#               Q2              35.125000   16         18.923077   52         16.181818   44         14.228782  1084         14.947368   38         14.789303  1234
#               Q3              25.392857   28         16.200000   65         19.674419   43         15.819556   992         13.931034   58         16.113828  1186
#               Q4              26.171429   35         18.635135   74         18.500000   52         15.209738  1068         17.033333   30         15.895155  1259
#          2012 N/A             29.315789   76         22.701299  231         19.245399  163         13.914185  4801         18.504762  105         14.760789  5376
#               Q1              26.071429   14         21.688525   61         19.692308   39         14.219780  1092         17.080000   25         14.956133  1231
#               Q2              29.733333   15         25.888889   63         18.700000   40         13.996473  1134         19.914286   35         15.069153  1287
#               Q3              33.000000   23         20.846154   52         21.459459   37         14.154589  1242         19.125000   24         15.004354  1378
#               Q4              27.416667   24         21.927273   55         17.595745   47         13.369842  1333         17.142857   21         14.103378  1480
#          2013 N/A             27.320513   78         20.352381  210         18.694805  154         13.715765  5696         15.000000   62         14.248226  6200
#               Q1              35.083333   24         20.925926   54         21.148936   47         14.213355  1228         18.727273   11         15.121701  1364
#               Q2              22.863636   22         17.754386   57         17.446429   56         13.530774  1511         14.320000   25         13.940754  1671
#               Q3              28.357143   14         18.830508   59         18.000000   28         13.163376  1469         17.266667   15         13.632808  1585
#               Q4              21.611111   18         25.525000   40         17.565217   23         14.038306  1488          9.727273   11         14.436709  1580
#          2014 N/A             30.508475   59         21.717842  241         22.960000  200         14.864293  6234         30.825397   63         15.629248  6797
#               Q1              20.000000    5         17.615385   52         21.615385   39         14.160542  1551         14.529412   17         14.464543  1664
#               Q2              35.058824   17         23.672414   58         24.444444   45         14.211392  1580         11.800000   15         14.985423  1715
#               Q3              29.368421   19         20.484375   64         22.275862   58         16.122147  1621         82.466667   15         17.181767  1777
#               Q4              30.333333   18         24.388060   67         23.396552   58         14.921053  1482         17.562500   16         15.801950  1641
#          2015 N/A             28.524590   61         20.034146  205         24.602679  224         14.970609  5580         15.500000   70         15.631759  6140
#               Q1              28.571429   14         20.693548   62         23.656250   64         14.686329  1441         12.550000   20         15.372267  1601
#               Q2              27.800000   20         17.972222   36         25.528302   53         14.993948  1487         14.944444   18         15.564436  1614
#               Q3              28.312500   16         20.949153   59         27.613636   44         14.772830  1325         20.133333   15         15.613434  1459
#               Q4              30.090909   11         19.604167   48         22.682540   63         15.450641  1327         15.470588   17         16.007503  1466
#          2016 N/A             36.203704   54         22.802632  152         25.988889  270         15.053361  5266         13.612903   31         15.958947  5773
#               Q1              43.900000   20         22.465116   43         28.567568   74         15.789324  1405         14.100000   10         16.934923  1552
#               Q2              37.066667   15         22.472222   36         27.333333   69         14.719792  1349         11.777778    9         15.706360  1478
#               Q3              28.200000   10         24.486486   37         24.080000   75         15.006033  1326         16.250000    4         15.810606  1452
#               Q4              26.555556    9         21.805556   36         23.288462   52         14.613828  1186         13.750000    8         15.241673  1291
#          2017 N/A             35.290323   31         24.232877  146         26.287671  219         15.600040  4948         17.421053   38         16.395392  5382
#               Q1              34.333333    6         21.962963   27         27.350000   40         15.790030  1324         31.363636   11         16.437500  1408
#               Q2              44.500000    8         25.413043   46         27.318182   66         15.449275  1242         10.625000    8         16.497080  1370
#               Q3              33.142857    7         23.850000   40         23.810345   58         15.290786  1183         11.700000   10         16.003852  1298
#               Q4              30.000000   10         24.909091   33         26.890909   55         15.851543  1199         12.777778    9         16.632466  1306
#          2018 N/A             35.361111   36         27.310078  129         28.097222  144         15.977807  4551         21.142857   21         16.800041  4881
#               Q1              39.500000    4         31.620690   29         32.259259   27         16.331683  1212         15.857143    7         17.084441  1279
#               Q2              36.166667   12         25.360000   25         28.365854   41         15.754460  1177         27.166667    6         16.603489  1261
#               Q3              28.125000    8         28.171429   35         25.545455   44         15.780579  1071         21.500000    4         16.628227  1162
#               Q4              38.000000   12         24.650000   40         27.750000   32         16.019248  1091         21.000000    4         16.871077  1179
#          2019 N/A             43.358974   39         24.739130   92         27.660099  203         16.390690  4597         30.187500   32         17.307274  4963
#               Q1              49.533333   15         22.692308   26         28.596154   52         16.830481  1227          9.800000    5         17.750943  1325
#               Q2              42.000000   10         25.000000   22         26.948276   58         16.181985  1088         14.875000    8         17.080944  1186
#               Q3              37.375000    8         27.384615   26         28.538462   52         15.656034  1160         58.909091   11         16.948290  1257
#               Q4              38.166667    6         23.555556   18         26.365854   41         16.871658  1122         18.750000    8         17.417573  1195
#          2020 N/A             72.260870   23         34.659574   94         33.135294  170         19.856527  3478         17.913043   23         21.126188  3788
#               Q1              32.000000    4         18.769231   39         28.853659   41         15.916834   998         11.750000    8         16.533945  1090
#               Q2              34.666667    3         23.000000   12         23.000000   21         18.950368   544         24.800000    5         19.309402   585
#               Q3              49.375000    8         30.619048   21         34.274510   51         22.093248   933         13.000000    2         23.078818  1015
#               Q4             129.375000    8         73.045455   22         38.929825   57         22.187438  1003         21.000000    8         24.847905  1098
#          2021 Q1              40.666667    3         32.869565   23         35.000000   45         19.776965  1094         12.750000    8         20.623188  1173

# %%
df.to_csv(path_or_buf = '~/FCSQ_data/timeliness.csv',index=False)
